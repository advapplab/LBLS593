# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      -------------------------------------- 293.3/293.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.4)
# Collecting matplotlib!=3.6.1,>=3.1
#   Downloading matplotlib-3.7.1-cp310-cp310-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.5)
# Requirement already satisfied: six>=1.5 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: matplotlib, seaborn
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.1
#     Uninstalling matplotlib-3.6.1:
#       Successfully uninstalled matplotlib-3.6.1
# Successfully installed matplotlib-3.7.1 seaborn-0.12.2
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
br_pd = pd.read_csv('./data/br.csv')
viscode_pd = pd.read_csv('./data/viscode.csv')
score_pd = pd.read_csv('./data/score.csv')
srl_s_pd = pd.read_csv('./data/srl_strategy.csv')
srl_m_pd = pd.read_csv('./data/srl_motivation.csv')
sill_pd = pd.read_csv('./data/sill.csv')

# %% [markdown]
# # Data Characteristics

# %% [markdown]
# ## score

# %%
score_pd.nunique()
# Out:
# userid    557
# score      76
# class      11
# dtype: int64

# %%
plt.figure(figsize=(5, 2))
score_pd['score'].hist(bins=10)
plt.title('Score Distribution of All Student')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.savefig('./data_plot/score')
plt.show()

# %%
plt.figure(figsize=(5, 2))
score_pd[score_pd['class']=='h']['score'].hist(bins=10)

plt.title('Score Distribution of Class H(Non-EMI)')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.show()

# %%
plt.figure(figsize=(5, 2))
score_pd[score_pd['class']=='i']['score'].hist(bins=10)

plt.title('Score Distribution of Class I(EMI)')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.show()

# %%
plt.figure(figsize=(5, 2))
score_pd[score_pd['class']=='j']['score'].hist(bins=10)

plt.title('Score Distribution of Class I(EMI)')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.show()

# %%
def Plot_Score():
    classID = 'abcdefghij'
    for cid in classID :
        print(cid)
        plt.figure(figsize=(5, 2))
        score_pd[score_pd['class']==cid]['score'].hist(bins=10)

        plt.title('Score Distribution of Class ' + cid )
        plt.ylabel('Numbers')
        plt.xlabel('Score')
        save_path = './data_plot/score_'+cid
        plt.savefig(save_path)
        plt.show()
Plot_Score()
# Out:
# a
# b
# c
# d
# e
# f
# g
# h
# i
# j

# %%
score_pd
# Out:
#                                userid  score class
# 0    faceedc2fdf78a0f24b2e469c8072881     68     a
# 1    3017f8db51adce97836bfbd2a5e76bc4     29     a
# 2    fcd714c799381d83a55d85fc8813aaf2     44     a
# 3    822f678c2e95794c527b1f854bd35006     74     a
# 4    52a83b516a01c8cefdb16bd3acb4b844     76     a
# ..                                ...    ...   ...
# 552  42eb1587254f1e97b42bc7c8e51013e4     61     k
# 553  255fd92615ae12a8684a2fa8be8e727e     72     k
# 554  ef8caaf8bbb3a63ef790ebf6b01a3b50     82     k
# 555  6206ac11031f917f92e2c504ac54b4fc     81     k
# 556  244813a7818ad2f397b015050e033321     69     k
#
# [557 rows x 3 columns]

# %% [markdown]
# # Data Statistics

# %% [markdown]
# # SILL

# %%
sill_pd = pd.read_csv('./data/sill.csv')
sill_pd
# Out:
#                                userid  s_1  s_2  s_3  s_4  s_5  s_6  s_7  s_8  \
# 0    b1dfc5c6ec04d46d1823c5fa972ad320    5    5    5    5    1    1    5    1
# 1    4e3519d7eafbfccdae231756fcf2ce9c    3    3    3    3    3    3    3    3
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698    5    5    5    4    5    5    5    5
# 3    379bbc4c2c728db0a249e8c4e6b621af    3    3    3    3    3    3    5    3
# 4    a92f1708363527a34d93b0bc7840262c    3    4    3    3    2    2    4    4
# ..                                ...  ...  ...  ...  ...  ...  ...  ...  ...
# 287  7caa5e63a94c013842534b6ac9abc8c5    4    3    4    3    3    4    3    3
# 288  65ea88037d2e504521081a28edcffa68    2    3    2    3    3    2    2    2
# 289  2abeed29705e8047bd0a7af55bbda567    2    2    3    2    2    3    3    2
# 290  a0332283e1713ef0d11504ad72bd93ee    2    2    2    2    2    2    2    2
# 291  1a79f93f5657aafdd595150d86125505    3    2    4    3    3    3    2    4
#
#      s_9  ...  s_39  s_40  s_41  s_42  s_43  s_44  s_45  s_46  s_47  s_48
# 0      5  ...     5     1     1     5     5     5     1     1     1     5
# 1      3  ...     4     4     3     4     4     4     3     3     4     3
# 2      5  ...     5     5     4     5     5     4     3     5     5     4
# 3      5  ...     5     1     4     5     5     5     5     5     5     5
# 4      3  ...     4     3     3     3     4     3     2     3     2     3
# ..   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 287    4  ...     3     2     1     2     3     3     3     3     3     4
# 288    2  ...     3     3     1     2     3     2     2     2     3     2
# 289    2  ...     3     3     1     2     3     3     1     2     2     3
# 290    1  ...     1     1     1     1     2     2     1     1     1     1
# 291    3  ...     2     3     1     1     4     3     2     2     2     3
#
# [292 rows x 49 columns]

# %%
# Calculate Standard Deviation & Delete the data which sd=0 
question_list = sill_pd.columns[1:49]
sill_pd['sd'] = sill_pd[question_list].std(axis=1)
keep_list = sill_pd['sd'] > 0
sill_pd = sill_pd[keep_list]

'''
    Merge by Category 
    ---------------------------
    category      : Question number
    ---------------------------
    memory        : 1-8 (8)
    cognitive     : 9-21 (13)
    compensation  : 22-27 (6)
    metacognitive : 28-36 (9)
    affective     : 37-42 (6)
    social        : 43-48 (6)
'''

memory_list = sill_pd.columns[1:9]
cognitive_list = sill_pd.columns[9:22]
compensation_list = sill_pd.columns[22:28]
metacognitive_list = sill_pd.columns[28:37]
affective_list = sill_pd.columns[37:43]
social_list = sill_pd.columns[43:49]

sill_pd['memory'] = sill_pd[memory_list].sum(axis=1)/8
sill_pd['cognitive'] = sill_pd[cognitive_list].sum(axis=1)/13
sill_pd['compensation'] = sill_pd[compensation_list].sum(axis=1)/6
sill_pd['metacognitive'] = sill_pd[metacognitive_list].sum(axis=1)/9
sill_pd['affective'] = sill_pd[affective_list].sum(axis=1)/6
sill_pd['social'] = sill_pd[social_list].sum(axis=1)/6

# keep data with same category
keep_list = ['userid', 'memory', 'cognitive', 'compensation', 'metacognitive', 'affective', 'social']
sill_pd = sill_pd[keep_list]
sill_pd = sill_pd.reset_index()
sill_pd = sill_pd.drop('index', axis=1)
sill_pd
# Out:
# /tmp/ipykernel_169427/1379482121.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['memory'] = sill_pd[memory_list].sum(axis=1)/8
# /tmp/ipykernel_169427/1379482121.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['cognitive'] = sill_pd[cognitive_list].sum(axis=1)/13
# /tmp/ipykernel_169427/1379482121.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['compensation'] = sill_pd[compensation_list].sum(axis=1)/6
# /tmp/ipykernel_169427/1379482121.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['metacognitive'] = sill_pd[metacognitive_list].sum(axis=1)/9
# /tmp/ipykernel_169427/1379482121.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['affective'] = sill_pd[affective_list].sum(axis=1)/6
# /tmp/ipykernel_169427/1379482121.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['social'] = sill_pd[social_list].sum(axis=1)/6
#                                userid  memory  cognitive  compensation  \
# 0    b1dfc5c6ec04d46d1823c5fa972ad320   3.500   4.307692      3.333333
# 1    4e3519d7eafbfccdae231756fcf2ce9c   3.000   3.000000      2.833333
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698   4.875   4.846154      4.500000
# 3    379bbc4c2c728db0a249e8c4e6b621af   3.250   5.000000      4.666667
# 4    a92f1708363527a34d93b0bc7840262c   3.125   3.538462      3.833333
# ..                                ...     ...        ...           ...
# 282  7caa5e63a94c013842534b6ac9abc8c5   3.375   3.076923      3.500000
# 283  65ea88037d2e504521081a28edcffa68   2.375   2.307692      2.666667
# 284  2abeed29705e8047bd0a7af55bbda567   2.375   2.538462      2.833333
# 285  a0332283e1713ef0d11504ad72bd93ee   2.000   1.153846      1.500000
# 286  1a79f93f5657aafdd595150d86125505   3.000   3.000000      3.333333
#
#      metacognitive  affective    social
# 0         5.000000   3.500000  3.000000
# 1         3.000000   3.833333  3.500000
# 2         4.888889   4.500000  4.333333
# 3         4.666667   3.833333  5.000000
# 4         3.888889   3.500000  2.833333
# ..             ...        ...       ...
# 282       3.111111   2.500000  3.166667
# 283       2.000000   2.333333  2.333333
# 284       2.222222   2.500000  2.333333
# 285       1.000000   1.000000  1.333333
# 286       3.000000   2.166667  2.666667
#
# [287 rows x 7 columns]

# %%
data = sill_pd.drop('userid', axis=1)
plt.figure(figsize=(10, 3))
data.boxplot()
plt.title('SILL Questionario')
plt.savefig('./data_plot/sill')
plt.show()

# %%
merged_pd = pd.merge(sill_pd, score_pd, on='userid', how='inner')
merged_pd
# Out:
#                                userid  memory  cognitive  compensation  \
# 0    b1dfc5c6ec04d46d1823c5fa972ad320   3.500   4.307692      3.333333
# 1    4e3519d7eafbfccdae231756fcf2ce9c   3.000   3.000000      2.833333
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698   4.875   4.846154      4.500000
# 3    379bbc4c2c728db0a249e8c4e6b621af   3.250   5.000000      4.666667
# 4    a92f1708363527a34d93b0bc7840262c   3.125   3.538462      3.833333
# ..                                ...     ...        ...           ...
# 281  7caa5e63a94c013842534b6ac9abc8c5   3.375   3.076923      3.500000
# 282  65ea88037d2e504521081a28edcffa68   2.375   2.307692      2.666667
# 283  2abeed29705e8047bd0a7af55bbda567   2.375   2.538462      2.833333
# 284  a0332283e1713ef0d11504ad72bd93ee   2.000   1.153846      1.500000
# 285  1a79f93f5657aafdd595150d86125505   3.000   3.000000      3.333333
#
#      metacognitive  affective    social  score class
# 0         5.000000   3.500000  3.000000     90     b
# 1         3.000000   3.833333  3.500000     72     b
# 2         4.888889   4.500000  4.333333     98     b
# 3         4.666667   3.833333  5.000000     94     b
# 4         3.888889   3.500000  2.833333     78     b
# ..             ...        ...       ...    ...   ...
# 281       3.111111   2.500000  3.166667     97     k
# 282       2.000000   2.333333  2.333333     97     k
# 283       2.222222   2.500000  2.333333     86     k
# 284       1.000000   1.000000  1.333333     75     k
# 285       3.000000   2.166667  2.666667     92     k
#
# [286 rows x 9 columns]

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b59e6_row0_col0, #T_b59e6_row1_col1, #T_b59e6_row2_col2, #T_b59e6_row3_col3, #T_b59e6_row4_col4, #T_b59e6_row5_col5, #T_b59e6_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b59e6_row0_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_b59e6_row0_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_b59e6_row0_col3, #T_b59e6_row3_col5, #T_b59e6_row5_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b59e6_row0_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_b59e6_row0_col5, #T_b59e6_row4_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b59e6_row0_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b59e6_row1_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_b59e6_row1_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_b59e6_row1_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_b59e6_row1_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_b59e6_row1_col5 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_b59e6_row1_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_b59e6_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b59e6_row2_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_b59e6_row2_col3 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_b59e6_row2_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b59e6_row2_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_b59e6_row2_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b59e6_row3_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_b59e6_row3_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_b59e6_row3_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_b59e6_row3_col4, #T_b59e6_row4_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_b59e6_row3_col6, #T_b59e6_row4_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b59e6_row4_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_b59e6_row4_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_b59e6_row4_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_b59e6_row5_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_b59e6_row5_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_b59e6_row5_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_b59e6_row5_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_b59e6_row5_col6, #T_b59e6_row6_col0, #T_b59e6_row6_col1, #T_b59e6_row6_col2, #T_b59e6_row6_col3, #T_b59e6_row6_col4, #T_b59e6_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b59e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b59e6_level0_col0" class="col_heading level0 col0" >memory</th>
#       <th id="T_b59e6_level0_col1" class="col_heading level0 col1" >cognitive</th>
#       <th id="T_b59e6_level0_col2" class="col_heading level0 col2" >compensation</th>
#       <th id="T_b59e6_level0_col3" class="col_heading level0 col3" >metacognitive</th>
#       <th id="T_b59e6_level0_col4" class="col_heading level0 col4" >affective</th>
#       <th id="T_b59e6_level0_col5" class="col_heading level0 col5" >social</th>
#       <th id="T_b59e6_level0_col6" class="col_heading level0 col6" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b59e6_level0_row0" class="row_heading level0 row0" >memory</th>
#       <td id="T_b59e6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b59e6_row0_col1" class="data row0 col1" >0.704032</td>
#       <td id="T_b59e6_row0_col2" class="data row0 col2" >0.543690</td>
#       <td id="T_b59e6_row0_col3" class="data row0 col3" >0.648986</td>
#       <td id="T_b59e6_row0_col4" class="data row0 col4" >0.587553</td>
#       <td id="T_b59e6_row0_col5" class="data row0 col5" >0.500364</td>
#       <td id="T_b59e6_row0_col6" class="data row0 col6" >-0.069890</td>
#     </tr>
#     <tr>
#       <th id="T_b59e6_level0_row1" class="row_heading level0 row1" >cognitive</th>
#       <td id="T_b59e6_row1_col0" class="data row1 col0" >0.704032</td>
#       <td id="T_b59e6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b59e6_row1_col2" class="data row1 col2" >0.737660</td>
#       <td id="T_b59e6_row1_col3" class="data row1 col3" >0.760102</td>
#       <td id="T_b59e6_row1_col4" class="data row1 col4" >0.555527</td>
#       <td id="T_b59e6_row1_col5" class="data row1 col5" >0.677194</td>
#       <td id="T_b59e6_row1_col6" class="data row1 col6" >-0.062287</td>
#     </tr>
#     <tr>
#       <th id="T_b59e6_level0_row2" class="row_heading level0 row2" >compensation</th>
#       <td id="T_b59e6_row2_col0" class="data row2 col0" >0.543690</td>
#       <td id="T_b59e6_row2_col1" class="data row2 col1" >0.737660</td>
#       <td id="T_b59e6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b59e6_row2_col3" class="data row2 col3" >0.621202</td>
#       <td id="T_b59e6_row2_col4" class="data row2 col4" >0.463279</td>
#       <td id="T_b59e6_row2_col5" class="data row2 col5" >0.640341</td>
#       <td id="T_b59e6_row2_col6" class="data row2 col6" >-0.039462</td>
#     </tr>
#     <tr>
#       <th id="T_b59e6_level0_row3" class="row_heading level0 row3" >metacognitive</th>
#       <td id="T_b59e6_row3_col0" class="data row3 col0" >0.648986</td>
#       <td id="T_b59e6_row3_col1" class="data row3 col1" >0.760102</td>
#       <td id="T_b59e6_row3_col2" class="data row3 col2" >0.621202</td>
#       <td id="T_b59e6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b59e6_row3_col4" class="data row3 col4" >0.742385</td>
#       <td id="T_b59e6_row3_col5" class="data row3 col5" >0.646581</td>
#       <td id="T_b59e6_row3_col6" class="data row3 col6" >-0.107385</td>
#     </tr>
#     <tr>
#       <th id="T_b59e6_level0_row4" class="row_heading level0 row4" >affective</th>
#       <td id="T_b59e6_row4_col0" class="data row4 col0" >0.587553</td>
#       <td id="T_b59e6_row4_col1" class="data row4 col1" >0.555527</td>
#       <td id="T_b59e6_row4_col2" class="data row4 col2" >0.463279</td>
#       <td id="T_b59e6_row4_col3" class="data row4 col3" >0.742385</td>
#       <td id="T_b59e6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b59e6_row4_col5" class="data row4 col5" >0.500659</td>
#       <td id="T_b59e6_row4_col6" class="data row4 col6" >-0.107494</td>
#     </tr>
#     <tr>
#       <th id="T_b59e6_level0_row5" class="row_heading level0 row5" >social</th>
#       <td id="T_b59e6_row5_col0" class="data row5 col0" >0.500364</td>
#       <td id="T_b59e6_row5_col1" class="data row5 col1" >0.677194</td>
#       <td id="T_b59e6_row5_col2" class="data row5 col2" >0.640341</td>
#       <td id="T_b59e6_row5_col3" class="data row5 col3" >0.646581</td>
#       <td id="T_b59e6_row5_col4" class="data row5 col4" >0.500659</td>
#       <td id="T_b59e6_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b59e6_row5_col6" class="data row5 col6" >-0.113500</td>
#     </tr>
#     <tr>
#       <th id="T_b59e6_level0_row6" class="row_heading level0 row6" >score</th>
#       <td id="T_b59e6_row6_col0" class="data row6 col0" >-0.069890</td>
#       <td id="T_b59e6_row6_col1" class="data row6 col1" >-0.062287</td>
#       <td id="T_b59e6_row6_col2" class="data row6 col2" >-0.039462</td>
#       <td id="T_b59e6_row6_col3" class="data row6 col3" >-0.107385</td>
#       <td id="T_b59e6_row6_col4" class="data row6 col4" >-0.107494</td>
#       <td id="T_b59e6_row6_col5" class="data row6 col5" >-0.113500</td>
#       <td id="T_b59e6_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                  memory  cognitive  compensation  metacognitive  affective  \
# memory         1.000000   0.704032      0.543690       0.648986   0.587553
# cognitive      0.704032   1.000000      0.737660       0.760102   0.555527
# compensation   0.543690   0.737660      1.000000       0.621202   0.463279
# metacognitive  0.648986   0.760102      0.621202       1.000000   0.742385
# affective      0.587553   0.555527      0.463279       0.742385   1.000000
# social         0.500364   0.677194      0.640341       0.646581   0.500659
# score         -0.069890  -0.062287     -0.039462      -0.107385  -0.107494
#
#                  social     score
# memory         0.500364 -0.069890
# cognitive      0.677194 -0.062287
# compensation   0.640341 -0.039462
# metacognitive  0.646581 -0.107385
# affective      0.500659 -0.107494
# social         1.000000 -0.113500
# score         -0.113500  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # SRL Motivation

# %%
srl_motivate_pd = pd.read_csv('./data/srl_motivation.csv')

# %%
# Calculate Standard Deviation & Delete the data which sd=0
question_list = srl_motivate_pd.columns[1:32]
srl_motivate_pd['sd'] = srl_motivate_pd[question_list].std(axis=1)
keep_list = srl_motivate_pd['sd'] > 0
srl_motivate_pd = srl_motivate_pd[keep_list]
srl_motivate_pd

'''
    Merge by Category 
    ---------------------------
    category      : Question number
    ---------------------------
    intrinsic       : 1-4 (4)
    extrinsic       : 5-8 (4)
    task_value      : 9-14 (6)
    control_beliefs : 15-18 (4)
    self_efficacy   : 19-26 (8)
    test_anxiety    : 27-31 (5)
'''

# classify data with same category
i = 1
intrinsic_goal_orientation = srl_motivate_pd.columns[i:i+4]
i = i + 4
extrinsic_goal_orientation = srl_motivate_pd.columns[i:i+4]
i = i + 4
task_value = srl_motivate_pd.columns[i:i+6]
i = i + 6
control_beliefs = srl_motivate_pd.columns[i:i+4]
i = i + 4
self_efficacy_and_performance = srl_motivate_pd.columns[i:i+8]
i = i + 8
test_anxiety = srl_motivate_pd.columns[i:i+5]


srl_motivate_pd['intrinsic'] = srl_motivate_pd[intrinsic_goal_orientation].sum(axis=1)/4
srl_motivate_pd['extrinsic'] = srl_motivate_pd[extrinsic_goal_orientation].sum(axis=1)/4
srl_motivate_pd['task_value'] = srl_motivate_pd[task_value].sum(axis=1)/6
srl_motivate_pd['control_beliefs'] = srl_motivate_pd[control_beliefs].sum(axis=1)/4
srl_motivate_pd['self_efficacy'] = srl_motivate_pd[self_efficacy_and_performance].sum(axis=1)/8
srl_motivate_pd['test_anxiety'] = srl_motivate_pd[test_anxiety].sum(axis=1)/5

# keep data with same category
keep_list = ['userid', 'intrinsic', 'extrinsic', 'task_value', 'control_beliefs', 'self_efficacy', 'test_anxiety']
srl_motivate_pd = srl_motivate_pd[keep_list]
srl_motivate_pd = srl_motivate_pd.reset_index()
srl_motivate_pd = srl_motivate_pd.drop('index', axis=1)
srl_motivate_pd
# Out:
#                                userid  intrinsic  extrinsic  task_value  \
# 0    b84f9624c8d995c6b945afc898bd9973       3.75       1.50    4.166667
# 1    481c56986ebae62c870b0da9bbafc5c6       4.50       4.50    4.500000
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698       5.00       4.50    5.000000
# 3    c054e8c731029ce6d73c784213513b09       4.25       5.00    4.000000
# 4    bebc49073c8a5def929612def946c281       3.25       3.50    3.833333
# ..                                ...        ...        ...         ...
# 356  756a144eb793664289f35819def10b2d       3.75       3.75    3.666667
# 357  2b2772f27fdb3d541eefbe4949774987       3.50       4.25    4.166667
# 358  ba2fa93a0d94592af0c6df03e5e25a62       3.75       3.75    4.166667
# 359  87c98766d4df3dc937ccd3f69d49caa5       4.75       3.25    4.000000
# 360  d1ed75d1b9300cf39b07c0f91062e075       4.50       3.75    4.333333
#
#      control_beliefs  self_efficacy  test_anxiety
# 0               3.50          3.375           1.6
# 1               4.50          4.500           4.6
# 2               5.00          4.750           3.2
# 3               4.50          4.125           4.4
# 4               4.00          4.000           1.0
# ..               ...            ...           ...
# 356             3.75          3.375           3.4
# 357             3.50          3.875           3.2
# 358             4.00          3.750           3.6
# 359             3.75          3.875           1.4
# 360             3.75          4.500           3.6
#
# [361 rows x 7 columns]

# %%
plt.figure(figsize=(10, 3))
srl_motivate_pd.boxplot()
plt.title('SRL Motivate Questionario')
plt.savefig('./data_plot/srl_motivation')
plt.show()

# %%
merged_pd = pd.merge(srl_motivate_pd, score_pd, on='userid', how='outer')

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e6c0c_row0_col0, #T_e6c0c_row1_col1, #T_e6c0c_row2_col2, #T_e6c0c_row3_col3, #T_e6c0c_row4_col4, #T_e6c0c_row5_col5, #T_e6c0c_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e6c0c_row0_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e6c0c_row0_col2 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_e6c0c_row0_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_e6c0c_row0_col4, #T_e6c0c_row2_col4 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_e6c0c_row0_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e6c0c_row0_col6, #T_e6c0c_row1_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e6c0c_row1_col0, #T_e6c0c_row2_col6 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e6c0c_row1_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_e6c0c_row1_col3, #T_e6c0c_row4_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_e6c0c_row1_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_e6c0c_row1_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e6c0c_row2_col0 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_e6c0c_row2_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_e6c0c_row2_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_e6c0c_row2_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e6c0c_row3_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_e6c0c_row3_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e6c0c_row3_col2, #T_e6c0c_row4_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_e6c0c_row3_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_e6c0c_row3_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e6c0c_row3_col6, #T_e6c0c_row6_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_e6c0c_row4_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_e6c0c_row4_col1, #T_e6c0c_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e6c0c_row4_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_e6c0c_row4_col5, #T_e6c0c_row5_col0, #T_e6c0c_row5_col2, #T_e6c0c_row5_col3, #T_e6c0c_row5_col4, #T_e6c0c_row5_col6, #T_e6c0c_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e6c0c_row5_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e6c0c_row6_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_e6c0c_row6_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_e6c0c_row6_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e6c0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6c0c_level0_col0" class="col_heading level0 col0" >intrinsic</th>
#       <th id="T_e6c0c_level0_col1" class="col_heading level0 col1" >extrinsic</th>
#       <th id="T_e6c0c_level0_col2" class="col_heading level0 col2" >task_value</th>
#       <th id="T_e6c0c_level0_col3" class="col_heading level0 col3" >control_beliefs</th>
#       <th id="T_e6c0c_level0_col4" class="col_heading level0 col4" >self_efficacy</th>
#       <th id="T_e6c0c_level0_col5" class="col_heading level0 col5" >test_anxiety</th>
#       <th id="T_e6c0c_level0_col6" class="col_heading level0 col6" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6c0c_level0_row0" class="row_heading level0 row0" >intrinsic</th>
#       <td id="T_e6c0c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e6c0c_row0_col1" class="data row0 col1" >0.180494</td>
#       <td id="T_e6c0c_row0_col2" class="data row0 col2" >0.612190</td>
#       <td id="T_e6c0c_row0_col3" class="data row0 col3" >0.514149</td>
#       <td id="T_e6c0c_row0_col4" class="data row0 col4" >0.563400</td>
#       <td id="T_e6c0c_row0_col5" class="data row0 col5" >-0.175916</td>
#       <td id="T_e6c0c_row0_col6" class="data row0 col6" >0.161212</td>
#     </tr>
#     <tr>
#       <th id="T_e6c0c_level0_row1" class="row_heading level0 row1" >extrinsic</th>
#       <td id="T_e6c0c_row1_col0" class="data row1 col0" >0.180494</td>
#       <td id="T_e6c0c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e6c0c_row1_col2" class="data row1 col2" >0.278620</td>
#       <td id="T_e6c0c_row1_col3" class="data row1 col3" >0.317771</td>
#       <td id="T_e6c0c_row1_col4" class="data row1 col4" >0.387205</td>
#       <td id="T_e6c0c_row1_col5" class="data row1 col5" >0.228789</td>
#       <td id="T_e6c0c_row1_col6" class="data row1 col6" >0.163326</td>
#     </tr>
#     <tr>
#       <th id="T_e6c0c_level0_row2" class="row_heading level0 row2" >task_value</th>
#       <td id="T_e6c0c_row2_col0" class="data row2 col0" >0.612190</td>
#       <td id="T_e6c0c_row2_col1" class="data row2 col1" >0.278620</td>
#       <td id="T_e6c0c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e6c0c_row2_col3" class="data row2 col3" >0.558728</td>
#       <td id="T_e6c0c_row2_col4" class="data row2 col4" >0.559025</td>
#       <td id="T_e6c0c_row2_col5" class="data row2 col5" >-0.088816</td>
#       <td id="T_e6c0c_row2_col6" class="data row2 col6" >0.215923</td>
#     </tr>
#     <tr>
#       <th id="T_e6c0c_level0_row3" class="row_heading level0 row3" >control_beliefs</th>
#       <td id="T_e6c0c_row3_col0" class="data row3 col0" >0.514149</td>
#       <td id="T_e6c0c_row3_col1" class="data row3 col1" >0.317771</td>
#       <td id="T_e6c0c_row3_col2" class="data row3 col2" >0.558728</td>
#       <td id="T_e6c0c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e6c0c_row3_col4" class="data row3 col4" >0.566994</td>
#       <td id="T_e6c0c_row3_col5" class="data row3 col5" >-0.101915</td>
#       <td id="T_e6c0c_row3_col6" class="data row3 col6" >0.191786</td>
#     </tr>
#     <tr>
#       <th id="T_e6c0c_level0_row4" class="row_heading level0 row4" >self_efficacy</th>
#       <td id="T_e6c0c_row4_col0" class="data row4 col0" >0.563400</td>
#       <td id="T_e6c0c_row4_col1" class="data row4 col1" >0.387205</td>
#       <td id="T_e6c0c_row4_col2" class="data row4 col2" >0.559025</td>
#       <td id="T_e6c0c_row4_col3" class="data row4 col3" >0.566994</td>
#       <td id="T_e6c0c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_e6c0c_row4_col5" class="data row4 col5" >-0.298536</td>
#       <td id="T_e6c0c_row4_col6" class="data row4 col6" >0.302128</td>
#     </tr>
#     <tr>
#       <th id="T_e6c0c_level0_row5" class="row_heading level0 row5" >test_anxiety</th>
#       <td id="T_e6c0c_row5_col0" class="data row5 col0" >-0.175916</td>
#       <td id="T_e6c0c_row5_col1" class="data row5 col1" >0.228789</td>
#       <td id="T_e6c0c_row5_col2" class="data row5 col2" >-0.088816</td>
#       <td id="T_e6c0c_row5_col3" class="data row5 col3" >-0.101915</td>
#       <td id="T_e6c0c_row5_col4" class="data row5 col4" >-0.298536</td>
#       <td id="T_e6c0c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_e6c0c_row5_col6" class="data row5 col6" >-0.124452</td>
#     </tr>
#     <tr>
#       <th id="T_e6c0c_level0_row6" class="row_heading level0 row6" >score</th>
#       <td id="T_e6c0c_row6_col0" class="data row6 col0" >0.161212</td>
#       <td id="T_e6c0c_row6_col1" class="data row6 col1" >0.163326</td>
#       <td id="T_e6c0c_row6_col2" class="data row6 col2" >0.215923</td>
#       <td id="T_e6c0c_row6_col3" class="data row6 col3" >0.191786</td>
#       <td id="T_e6c0c_row6_col4" class="data row6 col4" >0.302128</td>
#       <td id="T_e6c0c_row6_col5" class="data row6 col5" >-0.124452</td>
#       <td id="T_e6c0c_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                  intrinsic  extrinsic  task_value  control_beliefs  \
# intrinsic         1.000000   0.180494    0.612190         0.514149
# extrinsic         0.180494   1.000000    0.278620         0.317771
# task_value        0.612190   0.278620    1.000000         0.558728
# control_beliefs   0.514149   0.317771    0.558728         1.000000
# self_efficacy     0.563400   0.387205    0.559025         0.566994
# test_anxiety     -0.175916   0.228789   -0.088816        -0.101915
# score             0.161212   0.163326    0.215923         0.191786
#
#                  self_efficacy  test_anxiety     score
# intrinsic             0.563400     -0.175916  0.161212
# extrinsic             0.387205      0.228789  0.163326
# task_value            0.559025     -0.088816  0.215923
# control_beliefs       0.566994     -0.101915  0.191786
# self_efficacy         1.000000     -0.298536  0.302128
# test_anxiety         -0.298536      1.000000 -0.124452
# score                 0.302128     -0.124452  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # SRL Strategy

# %%
srl_strategy_pd = pd.read_csv('./data/srl_strategy.csv')

# %%
# Calculate Standard Deviation & Delete the data which sd=0
question_list = srl_strategy_pd.columns[1:51]
srl_strategy_pd['sd'] = srl_strategy_pd[question_list].std(axis=1)
keep_list = srl_strategy_pd['sd'] > 0
srl_strategy_pd = srl_strategy_pd[keep_list]


'''
    Merge by Category 
    ---------------------------
    category      : Question number
    ---------------------------
    rehearsal         : 1-4    (4)
    elaboration       : 5-10   (6)
    organization      : 11-14  (4)
    critical_thinking : 15-19  (5)
    metacognitive_self_regulation   : 20-31 (12)
    time_environment  : 32-39  (8)
    effort_regulation : 40-43  (4)
    peer_learning     : 44-46  (3)
    help_seeking      : 47-50  (4)
'''

# classify data with same category
i = 1
rehearsal = srl_strategy_pd.columns[i:i+4]
i = i + 4
elaboration = srl_strategy_pd.columns[i:i+6]
i = i + 6
organization = srl_strategy_pd.columns[i:i+4]
i = i + 4
critical_thinking = srl_strategy_pd.columns[i:i+5]
i = i + 5
metacognitive_self_regulation = srl_strategy_pd.columns[i:i+12]
i = i + 12
time_environment = srl_strategy_pd.columns[i:i+8]
i = i + 8
effort_regulation = srl_strategy_pd.columns[i:i+4]
i = i + 4
peer_learning = srl_strategy_pd.columns[i:i+3]
i = i + 3
help_seeking = srl_strategy_pd.columns[i:i+4]


# avg
srl_strategy_pd['rehearsal'] = srl_strategy_pd[rehearsal].sum(axis=1) / 4
srl_strategy_pd['elaboration'] = srl_strategy_pd[elaboration].sum(axis=1) / 6
srl_strategy_pd['organization'] = srl_strategy_pd[organization].sum(axis=1) / 4
srl_strategy_pd['critical_thinking'] = srl_strategy_pd[critical_thinking].sum(axis=1)/ 5
srl_strategy_pd['metacognitive_self_regulation'] = srl_strategy_pd[metacognitive_self_regulation].sum(axis=1)/12
srl_strategy_pd['time_environment'] = srl_strategy_pd[time_environment].sum(axis=1)/8
srl_strategy_pd['effort_regulation'] = srl_strategy_pd[effort_regulation].sum(axis=1)/4
srl_strategy_pd['peer_learning'] = srl_strategy_pd[peer_learning].sum(axis=1)/3
srl_strategy_pd['help_seeking'] = srl_strategy_pd[help_seeking].sum(axis=1)/4

# keep data with same category
keep_list = ['userid', 'rehearsal', 'elaboration', 'organization', 'critical_thinking', 
             'metacognitive_self_regulation', 'time_environment', 'effort_regulation', 'peer_learning', 'help_seeking']
srl_strategy_pd = srl_strategy_pd[keep_list]
srl_strategy_pd = srl_strategy_pd.reset_index()
srl_strategy_pd = srl_strategy_pd.drop('index', axis=1)
srl_strategy_pd
# Out:
#                                userid  rehearsal  elaboration  organization  \
# 0    b64ce7758b9f7e58f1ad8bbcf7811e7d       4.75     4.666667          5.00
# 1    0cebfa477ed3e2e0c5a3f9aa96c23698       4.00     4.500000          4.50
# 2    0a715a568a054d7996fcbcbf17b36551       3.75     3.833333          3.75
# 3    ca7f48cb0d61ed7c967adf1a0010367e       4.75     3.166667          3.75
# 4    2979bd5d5a584c2aa70f4a434412bc2b       4.00     4.166667          4.00
# ..                                ...        ...          ...           ...
# 331  b8ef6c606080652d058e67045887e847       4.25     4.333333          4.75
# 332  f5095309462e250ecd736e7260a50fa7       4.25     4.166667          4.75
# 333  b65e40d9bac3a1cec9291eadf905321c       3.50     3.333333          4.00
# 334  05befdd4658ac20a97d8e1c1c747ed28       3.25     3.666667          4.00
# 335  5c5ed1630835c3c074ad292333a47afd       3.75     4.166667          4.00
#
#      critical_thinking  metacognitive_self_regulation  time_environment  \
# 0                  3.2                       4.000000             3.375
# 1                  4.0                       4.000000             4.125
# 2                  3.8                       4.000000             3.375
# 3                  3.4                       3.500000             3.250
# 4                  3.8                       3.083333             4.000
# ..                 ...                            ...               ...
# 331                4.0                       3.833333             3.500
# 332                3.6                       3.833333             3.625
# 333                3.2                       3.416667             3.500
# 334                4.2                       3.000000             3.250
# 335                4.0                       4.250000             3.500
#
#      effort_regulation  peer_learning  help_seeking
# 0                 3.00       4.000000          4.75
# 1                 4.25       3.666667          4.00
# 2                 3.00       3.333333          3.25
# 3                 3.75       2.333333          3.25
# 4                 3.25       2.666667          3.50
# ..                 ...            ...           ...
# 331               3.25       3.333333          4.00
# 332               3.50       2.333333          4.25
# 333               4.00       3.333333          3.50
# 334               3.75       4.000000          3.50
# 335               3.75       3.666667          3.00
#
# [336 rows x 10 columns]

# %%
plt.figure(figsize=(10, 3))
srl_strategy_pd.boxplot()
plt.xticks(rotation=45)
plt.title('SRL Strategy Questionario')
results_path= './data_plot/srl_strategy'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
plt.show()

# %%
merged_pd = pd.merge(srl_strategy_pd, score_pd, on='userid', how='outer')

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ef21f_row0_col0, #T_ef21f_row1_col1, #T_ef21f_row2_col2, #T_ef21f_row3_col3, #T_ef21f_row4_col4, #T_ef21f_row5_col5, #T_ef21f_row6_col6, #T_ef21f_row7_col7, #T_ef21f_row8_col8, #T_ef21f_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ef21f_row0_col1, #T_ef21f_row1_col0, #T_ef21f_row1_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_ef21f_row0_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_ef21f_row0_col3, #T_ef21f_row0_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ef21f_row0_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ef21f_row0_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_ef21f_row0_col7, #T_ef21f_row3_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ef21f_row0_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ef21f_row0_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ef21f_row1_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ef21f_row1_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_ef21f_row1_col5, #T_ef21f_row3_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_ef21f_row1_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ef21f_row1_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ef21f_row1_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ef21f_row1_col9, #T_ef21f_row5_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_ef21f_row2_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ef21f_row2_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ef21f_row2_col3, #T_ef21f_row8_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ef21f_row2_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ef21f_row2_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_ef21f_row2_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ef21f_row2_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ef21f_row2_col8 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ef21f_row2_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ef21f_row3_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ef21f_row3_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_ef21f_row3_col2, #T_ef21f_row8_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ef21f_row3_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ef21f_row3_col7, #T_ef21f_row6_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ef21f_row3_col8, #T_ef21f_row5_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ef21f_row3_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ef21f_row4_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ef21f_row4_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_ef21f_row4_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_ef21f_row4_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_ef21f_row4_col5 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_ef21f_row4_col6 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_ef21f_row4_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ef21f_row4_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ef21f_row4_col9 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ef21f_row5_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ef21f_row5_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_ef21f_row5_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_ef21f_row5_col3, #T_ef21f_row8_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ef21f_row5_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_ef21f_row5_col6 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_ef21f_row5_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ef21f_row6_col0, #T_ef21f_row9_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ef21f_row6_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ef21f_row6_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ef21f_row6_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ef21f_row6_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ef21f_row6_col7, #T_ef21f_row6_col8, #T_ef21f_row7_col1, #T_ef21f_row7_col4, #T_ef21f_row7_col5, #T_ef21f_row7_col6, #T_ef21f_row7_col9, #T_ef21f_row9_col0, #T_ef21f_row9_col2, #T_ef21f_row9_col3, #T_ef21f_row9_col4, #T_ef21f_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ef21f_row6_col9, #T_ef21f_row7_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ef21f_row7_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ef21f_row7_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ef21f_row7_col8, #T_ef21f_row9_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_ef21f_row8_col2, #T_ef21f_row8_col4 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_ef21f_row8_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ef21f_row8_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_ef21f_row8_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ef21f_row8_col9 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_ef21f_row9_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ef21f_row9_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ef21f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef21f_level0_col0" class="col_heading level0 col0" >rehearsal</th>
#       <th id="T_ef21f_level0_col1" class="col_heading level0 col1" >elaboration</th>
#       <th id="T_ef21f_level0_col2" class="col_heading level0 col2" >organization</th>
#       <th id="T_ef21f_level0_col3" class="col_heading level0 col3" >critical_thinking</th>
#       <th id="T_ef21f_level0_col4" class="col_heading level0 col4" >metacognitive_self_regulation</th>
#       <th id="T_ef21f_level0_col5" class="col_heading level0 col5" >time_environment</th>
#       <th id="T_ef21f_level0_col6" class="col_heading level0 col6" >effort_regulation</th>
#       <th id="T_ef21f_level0_col7" class="col_heading level0 col7" >peer_learning</th>
#       <th id="T_ef21f_level0_col8" class="col_heading level0 col8" >help_seeking</th>
#       <th id="T_ef21f_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef21f_level0_row0" class="row_heading level0 row0" >rehearsal</th>
#       <td id="T_ef21f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ef21f_row0_col1" class="data row0 col1" >0.588603</td>
#       <td id="T_ef21f_row0_col2" class="data row0 col2" >0.599650</td>
#       <td id="T_ef21f_row0_col3" class="data row0 col3" >0.327037</td>
#       <td id="T_ef21f_row0_col4" class="data row0 col4" >0.517998</td>
#       <td id="T_ef21f_row0_col5" class="data row0 col5" >0.397727</td>
#       <td id="T_ef21f_row0_col6" class="data row0 col6" >0.198176</td>
#       <td id="T_ef21f_row0_col7" class="data row0 col7" >0.090423</td>
#       <td id="T_ef21f_row0_col8" class="data row0 col8" >0.332098</td>
#       <td id="T_ef21f_row0_col9" class="data row0 col9" >0.080378</td>
#     </tr>
#     <tr>
#       <th id="T_ef21f_level0_row1" class="row_heading level0 row1" >elaboration</th>
#       <td id="T_ef21f_row1_col0" class="data row1 col0" >0.588603</td>
#       <td id="T_ef21f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ef21f_row1_col2" class="data row1 col2" >0.529715</td>
#       <td id="T_ef21f_row1_col3" class="data row1 col3" >0.581593</td>
#       <td id="T_ef21f_row1_col4" class="data row1 col4" >0.604303</td>
#       <td id="T_ef21f_row1_col5" class="data row1 col5" >0.408766</td>
#       <td id="T_ef21f_row1_col6" class="data row1 col6" >0.229022</td>
#       <td id="T_ef21f_row1_col7" class="data row1 col7" >0.076716</td>
#       <td id="T_ef21f_row1_col8" class="data row1 col8" >0.326828</td>
#       <td id="T_ef21f_row1_col9" class="data row1 col9" >0.121306</td>
#     </tr>
#     <tr>
#       <th id="T_ef21f_level0_row2" class="row_heading level0 row2" >organization</th>

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                                rehearsal  elaboration  organization  \
# rehearsal                       1.000000     0.588603      0.599650
# elaboration                     0.588603     1.000000      0.529715
# organization                    0.599650     0.529715      1.000000
# critical_thinking               0.327037     0.581593      0.310696
# metacognitive_self_regulation   0.517998     0.604303      0.493518
# time_environment                0.397727     0.408766      0.376117
# effort_regulation               0.198176     0.229022      0.269686
# peer_learning                   0.090423     0.076716      0.181552
# help_seeking                    0.332098     0.326828      0.361303
# score                           0.080378     0.121306      0.053085
#
#                                critical_thinking  \
# rehearsal                               0.327037
# elaboration                             0.581593
# organization                            0.310696
# critical_thinking                       1.000000
# metacognitive_self_regulation           0.487076
# time_environment                        0.248221
# effort_regulation                       0.089075
# peer_learning                           0.119525
# help_seeking                            0.243916
# score                                   0.046734
#
#                                metacognitive_self_regulation  \
# rehearsal                                           0.517998
# elaboration                                         0.604303
# organization                                        0.493518
# critical_thinking                                   0.487076
# metacognitive_self_regulation                       1.000000
# time_environment                                    0.574532
# effort_regulation                                   0.422965
# peer_learning                                       0.112884
# help_seeking                                        0.403490
# score                                               0.113404
#
#                                time_environment  effort_regulation  \
# rehearsal                              0.397727           0.198176
# elaboration                            0.408766           0.229022
# organization                           0.376117           0.269686
# critical_thinking                      0.248221           0.089075
# metacognitive_self_regulation          0.574532           0.422965
# time_environment                       1.000000           0.604357
# effort_regulation                      0.604357           1.000000
# peer_learning                         -0.020078          -0.139479
# help_seeking                           0.244730           0.101273
# score                                  0.121559           0.005040
#
#                                peer_learning  help_seeking     score
# rehearsal                           0.090423      0.332098  0.080378
# elaboration                         0.076716      0.326828  0.121306
# organization                        0.181552      0.361303  0.053085
# critical_thinking                   0.119525      0.243916  0.046734
# metacognitive_self_regulation       0.112884      0.403490  0.113404
# time_environment                   -0.020078      0.244730  0.121559
# effort_regulation                  -0.139479      0.101273  0.005040
# peer_learning                       1.000000      0.224453 -0.078305
# help_seeking                        0.224453      1.000000  0.103907
# score                              -0.078305      0.103907  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # Questionario & Score (correlation)

# %%
merged_pd = pd.merge( srl_motivate_pd, srl_strategy_pd, on='userid', how='outer')
merged_pd = pd.merge( merged_pd, sill_pd, on='userid', how='outer')
merged_pd = pd.merge( merged_pd, score_pd, on='userid', how='outer')
merged_pd
# Out:
#                                userid  intrinsic  extrinsic  task_value  \
# 0    b84f9624c8d995c6b945afc898bd9973       3.75        1.5    4.166667
# 1    481c56986ebae62c870b0da9bbafc5c6       4.50        4.5    4.500000
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698       5.00        4.5    5.000000
# 3    c054e8c731029ce6d73c784213513b09       4.25        5.0    4.000000
# 4    bebc49073c8a5def929612def946c281       3.25        3.5    3.833333
# ..                                ...        ...        ...         ...
# 562  260ada5421c2bb6a0550e0382b19cf77        NaN        NaN         NaN
# 563  71df8625d52a709745029a9c376e926f        NaN        NaN         NaN
# 564  9b1b419000c3cb06980a79fb73030ae3        NaN        NaN         NaN
# 565  944ce9604c2ba043877f7e416606c2e5        NaN        NaN         NaN
# 566  1dadca83a65d798efbaecd04be608ab2        NaN        NaN         NaN
#
#      control_beliefs  self_efficacy  test_anxiety  rehearsal  elaboration  \
# 0                3.5          3.375           1.6       4.00     4.000000
# 1                4.5          4.500           4.6       3.00     3.500000
# 2                5.0          4.750           3.2       4.00     4.500000
# 3                4.5          4.125           4.4       5.00     4.333333
# 4                4.0          4.000           1.0       4.25     3.833333
# ..               ...            ...           ...        ...          ...
# 562              NaN            NaN           NaN        NaN          NaN
# 563              NaN            NaN           NaN        NaN          NaN
# 564              NaN            NaN           NaN        NaN          NaN
# 565              NaN            NaN           NaN        NaN          NaN
# 566              NaN            NaN           NaN        NaN          NaN
#
#      organization  ...  peer_learning  help_seeking  memory  cognitive  \
# 0             3.0  ...       5.000000           4.5   3.500   3.923077
# 1             3.5  ...       4.000000           4.0   3.625   3.615385
# 2             4.5  ...       3.666667           4.0   4.875   4.846154
# 3             5.0  ...       1.000000           5.0   2.125   1.923077
# 4             4.0  ...       3.000000           3.5   3.375   3.615385
# ..            ...  ...            ...           ...     ...        ...
# 562           NaN  ...            NaN           NaN     NaN        NaN
# 563           NaN  ...            NaN           NaN     NaN        NaN
# 564           NaN  ...            NaN           NaN     NaN        NaN
# 565           NaN  ...            NaN           NaN     NaN        NaN
# 566           NaN  ...            NaN           NaN     NaN        NaN
#
#      compensation  metacognitive  affective    social  score  class
# 0        3.833333       3.555556   3.833333  3.500000   81.0      b
# 1        4.166667       3.555556   3.166667  3.000000   84.0      b
# 2        4.500000       4.888889   4.500000  4.333333   98.0      b
# 3        1.833333       2.666667   3.000000  1.333333   90.0      b
# 4        4.333333       3.777778   3.500000  3.666667   85.0      b
# ..            ...            ...        ...       ...    ...    ...
# 562           NaN            NaN        NaN       NaN   76.0      k
# 563           NaN            NaN        NaN       NaN   75.0      k
# 564           NaN            NaN        NaN       NaN   88.0      k
# 565           NaN            NaN        NaN       NaN   90.0      k
# 566           NaN            NaN        NaN       NaN   72.0      k
#
# [567 rows x 24 columns]

# %%
plt.figure(figsize=(15, 5))
merged_pd.drop('score', axis=1).boxplot()
plt.title('Questionario')
plt.xticks(rotation='vertical')
plt.savefig('./data_plot/all_questionario', dpi='figure', bbox_inches='tight')
plt.show()

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_06dc2_row0_col0, #T_06dc2_row1_col1, #T_06dc2_row2_col2, #T_06dc2_row3_col3, #T_06dc2_row4_col4, #T_06dc2_row5_col5, #T_06dc2_row6_col6, #T_06dc2_row7_col7, #T_06dc2_row8_col8, #T_06dc2_row9_col9, #T_06dc2_row10_col10, #T_06dc2_row11_col11, #T_06dc2_row12_col12, #T_06dc2_row13_col13, #T_06dc2_row14_col14, #T_06dc2_row15_col15, #T_06dc2_row16_col16, #T_06dc2_row17_col17, #T_06dc2_row18_col18, #T_06dc2_row19_col19, #T_06dc2_row20_col20, #T_06dc2_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_06dc2_row0_col1, #T_06dc2_row17_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_06dc2_row0_col2, #T_06dc2_row10_col7 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_06dc2_row0_col3, #T_06dc2_row7_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_06dc2_row0_col4, #T_06dc2_row2_col4, #T_06dc2_row11_col12, #T_06dc2_row17_col18 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_06dc2_row0_col5, #T_06dc2_row18_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_06dc2_row0_col6, #T_06dc2_row9_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_06dc2_row0_col7, #T_06dc2_row10_col12 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_06dc2_row0_col8, #T_06dc2_row12_col17, #T_06dc2_row19_col14 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_06dc2_row0_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_06dc2_row0_col10, #T_06dc2_row1_col2, #T_06dc2_row9_col3, #T_06dc2_row10_col20, #T_06dc2_row19_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_06dc2_row0_col11, #T_06dc2_row3_col1, #T_06dc2_row3_col10, #T_06dc2_row16_col0, #T_06dc2_row17_col0, #T_06dc2_row18_col13 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_06dc2_row0_col12, #T_06dc2_row6_col18, #T_06dc2_row7_col20, #T_06dc2_row12_col0, #T_06dc2_row18_col2, #T_06dc2_row20_col7, #T_06dc2_row21_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_06dc2_row0_col13, #T_06dc2_row0_col15, #T_06dc2_row8_col15, #T_06dc2_row16_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_06dc2_row0_col14, #T_06dc2_row3_col15, #T_06dc2_row5_col18 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_06dc2_row0_col16, #T_06dc2_row9_col11, #T_06dc2_row16_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_06dc2_row0_col17, #T_06dc2_row2_col12, #T_06dc2_row2_col19, #T_06dc2_row4_col11, #T_06dc2_row7_col1, #T_06dc2_row7_col15 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_06dc2_row0_col18, #T_06dc2_row3_col21, #T_06dc2_row6_col1, #T_06dc2_row18_col7, #T_06dc2_row21_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_06dc2_row0_col19, #T_06dc2_row3_col11, #T_06dc2_row3_col13, #T_06dc2_row4_col19, #T_06dc2_row7_col14, #T_06dc2_row9_col8, #T_06dc2_row19_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_06dc2_row0_col20, #T_06dc2_row17_col14, #T_06dc2_row21_col9, #T_06dc2_row21_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_06dc2_row0_col21, #T_06dc2_row1_col21, #T_06dc2_row8_col18 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_06dc2_row1_col0, #T_06dc2_row2_col8, #T_06dc2_row2_col17, #T_06dc2_row2_col21, #T_06dc2_row7_col19, #T_06dc2_row14_col15, #T_06dc2_row15_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_06dc2_row1_col3, #T_06dc2_row4_col17, #T_06dc2_row4_col21, #T_06dc2_row8_col12 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_06dc2_row1_col4, #T_06dc2_row10_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_06dc2_row1_col5, #T_06dc2_row2_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_06dc2_row1_col6, #T_06dc2_row1_col12, #T_06dc2_row10_col19, #T_06dc2_row12_col5, #T_06dc2_row14_col5, #T_06dc2_row14_col16 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_06dc2_row1_col7, #T_06dc2_row7_col17, #T_06dc2_row14_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_06dc2_row1_col8, #T_06dc2_row14_col20, #T_06dc2_row18_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_06dc2_row1_col9, #T_06dc2_row2_col18, #T_06dc2_row10_col16, #T_06dc2_row15_col13, #T_06dc2_row19_col13, #T_06dc2_row21_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_06dc2_row1_col10, #T_06dc2_row7_col12, #T_06dc2_row9_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_06dc2_row1_col11, #T_06dc2_row2_col20, #T_06dc2_row3_col8, #T_06dc2_row5_col1, #T_06dc2_row11_col5, #T_06dc2_row14_col12, #T_06dc2_row15_col5, #T_06dc2_row16_col3, #T_06dc2_row19_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_06dc2_row1_col13, #T_06dc2_row1_col20, #T_06dc2_row3_col12, #T_06dc2_row4_col20, #T_06dc2_row12_col2, #T_06dc2_row13_col5, #T_06dc2_row13_col15, #T_06dc2_row15_col2, #T_06dc2_row19_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_06dc2_row1_col14, #T_06dc2_row1_col19, #T_06dc2_row2_col14, #T_06dc2_row3_col19, #T_06dc2_row4_col12, #T_06dc2_row6_col15, #T_06dc2_row10_col5, #T_06dc2_row11_col19, #T_06dc2_row13_col3, #T_06dc2_row18_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_06dc2_row1_col15, #T_06dc2_row18_col1, #T_06dc2_row21_col11 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_06dc2_row1_col16, #T_06dc2_row11_col15, #T_06dc2_row12_col1, #T_06dc2_row13_col7, #T_06dc2_row20_col14, #T_06dc2_row21_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_06dc2_row1_col17, #T_06dc2_row16_col1, #T_06dc2_row19_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_06dc2_row1_col18, #T_06dc2_row2_col15, #T_06dc2_row3_col16, #T_06dc2_row4_col13, #T_06dc2_row6_col17, #T_06dc2_row9_col12, #T_06dc2_row11_col1, #T_06dc2_row17_col12 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_06dc2_row2_col0, #T_06dc2_row18_col15 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_06dc2_row2_col1, #T_06dc2_row7_col18, #T_06dc2_row8_col13, #T_06dc2_row8_col19, #T_06dc2_row19_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_06dc2_row2_col3, #T_06dc2_row7_col6 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_06dc2_row2_col5, #T_06dc2_row4_col15, #T_06dc2_row13_col16, #T_06dc2_row20_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_06dc2_row2_col6, #T_06dc2_row8_col9, #T_06dc2_row8_col11, #T_06dc2_row14_col10 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_06dc2_row2_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_06dc2_row2_col10, #T_06dc2_row6_col11, #T_06dc2_row11_col2, #T_06dc2_row12_col10 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_06dc2_row2_col11, #T_06dc2_row9_col19, #T_06dc2_row9_col20 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_06dc2_row2_col13, #T_06dc2_row3_col14, #T_06dc2_row8_col20, #T_06dc2_row10_col18 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_06dc2_row2_col16, #T_06dc2_row3_col18, #T_06dc2_row4_col6, #T_06dc2_row11_col20, #T_06dc2_row13_col0, #T_06dc2_row14_col11, #T_06dc2_row19_col7, #T_06dc2_row20_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_06dc2_row3_col0, #T_06dc2_row9_col4, #T_06dc2_row19_col16 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_06dc2_row3_col2, #T_06dc2_row4_col2, #T_06dc2_row7_col10 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_06dc2_row3_col4, #T_06dc2_row18_col17 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_06dc2_row3_col5, #T_06dc2_row9_col21, #T_06dc2_row15_col3, #T_06dc2_row17_col13 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_06dc2_row3_col6, #T_06dc2_row11_col9 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_06dc2_row3_col7, #T_06dc2_row17_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_06dc2_row3_col9, #T_06dc2_row7_col16, #T_06dc2_row8_col0, #T_06dc2_row14_col6, #T_06dc2_row17_col7, #T_06dc2_row20_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_06dc2_row3_col17, #T_06dc2_row6_col13, #T_06dc2_row8_col16, #T_06dc2_row9_col1, #T_06dc2_row14_col21, #T_06dc2_row16_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_06dc2_row3_col20, #T_06dc2_row7_col5, #T_06dc2_row17_col6, #T_06dc2_row19_col10 {
#   background-color: #688aef;

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                                intrinsic  extrinsic  task_value  \
# intrinsic                       1.000000   0.180494    0.612190
# extrinsic                       0.180494   1.000000    0.278620
# task_value                      0.612190   0.278620    1.000000
# control_beliefs                 0.514149   0.317771    0.558728
# self_efficacy                   0.563400   0.387205    0.559025
# test_anxiety                   -0.175916   0.228789   -0.088816
# rehearsal                       0.369498   0.272788    0.371691
# elaboration                     0.457036   0.290042    0.523341
# organization                    0.235909   0.349090    0.338478
# critical_thinking               0.386047   0.196501    0.328715
# metacognitive_self_regulation   0.351086   0.359940    0.420815
# time_environment                0.310182   0.219470    0.355494
# effort_regulation               0.137566   0.164164    0.172609
# peer_learning                   0.127518   0.135747    0.149104
# help_seeking                    0.190901   0.305975    0.305511
# memory                          0.178922   0.078186    0.170880
# cognitive                       0.203186   0.100385    0.198680
# compensation                    0.202098  -0.007547    0.209996
# metacognitive                   0.193380   0.132954    0.201662
# affective                       0.143337   0.114244    0.172082
# social                          0.056255   0.155111    0.151105
# score                           0.161212   0.163326    0.215923
#
#                                control_beliefs  self_efficacy  test_anxiety  \
# intrinsic                             0.514149       0.563400     -0.175916
# extrinsic                             0.317771       0.387205      0.228789
# task_value                            0.558728       0.559025     -0.088816
# control_beliefs                       1.000000       0.566994     -0.101915
# self_efficacy                         0.566994       1.000000     -0.298536
# test_anxiety                         -0.101915      -0.298536      1.000000
# rehearsal                             0.313616       0.240259     -0.026267
# elaboration                           0.397065       0.484268     -0.110733
# organization                          0.275368       0.145854      0.088186
# critical_thinking                     0.268273       0.467306     -0.125000
# metacognitive_self_regulation         0.338186       0.381363      0.022722
# time_environment                      0.258543       0.279064      0.008911
# effort_regulation                     0.104929       0.117093      0.078595
# peer_learning                         0.170635       0.116029      0.011002
# help_seeking                          0.310995       0.210076      0.077664
# memory                                0.062442       0.104455      0.006449
# cognitive                             0.158872       0.262210     -0.084629
# compensation                          0.094650       0.298363     -0.130848
# metacognitive                         0.170433       0.213835      0.018024
# affective                             0.117353       0.142173      0.070614
# social                                0.048228       0.153123      0.037174
# score                                 0.191786       0.302128     -0.124452
#
#                                rehearsal  elaboration  organization  \
# intrinsic                       0.369498     0.457036      0.235909
# extrinsic                       0.272788     0.290042      0.349090
# task_value                      0.371691     0.523341      0.338478
# control_beliefs                 0.313616     0.397065      0.275368
# self_efficacy                   0.240259     0.484268      0.145854
# test_anxiety                   -0.026267    -0.110733      0.088186
# rehearsal                       1.000000     0.588603      0.599650
# elaboration                     0.588603     1.000000      0.529715
# organization                    0.599650     0.529715      1.000000
# critical_thinking               0.327037     0.581593      0.310696
# metacognitive_self_regulation   0.517998     0.604303      0.493518
# time_environment                0.397727     0.408766      0.376117
# effort_regulation               0.198176     0.229022      0.269686
# peer_learning                   0.090423     0.076716      0.181552
# help_seeking                    0.332098     0.326828      0.361303
# memory                          0.193782     0.244943      0.176958
# cognitive                       0.213244     0.292877      0.132996
# compensation                    0.123616     0.277655      0.107355
# metacognitive                   0.182301     0.197955      0.166551
# affective                       0.215336     0.178763      0.155689
# social                          0.096930     0.186503      0.164880
# score                           0.080378     0.121306      0.053085
#
#                                critical_thinking  ...  effort_regulation  \
# intrinsic                               0.386047  ...           0.137566
# extrinsic                               0.196501  ...           0.164164
# task_value                              0.328715  ...           0.172609
# control_beliefs                         0.268273  ...           0.104929
# self_efficacy                           0.467306  ...           0.117093
# test_anxiety                           -0.125000  ...           0.078595
# rehearsal                               0.327037  ...           0.198176
# elaboration                             0.581593  ...           0.229022
# organization                            0.310696  ...           0.269686
# critical_thinking                       1.000000  ...           0.089075
# metacognitive_self_regulation           0.487076  ...           0.422965
# time_environment                        0.248221  ...           0.604357
# effort_regulation                       0.089075  ...           1.000000
# peer_learning                           0.119525  ...          -0.139479
# help_seeking                            0.243916  ...           0.101273
# memory                                  0.287102  ...          -0.038778
# cognitive                               0.397161  ...           0.007689
# compensation                            0.381440  ...           0.086632
# metacognitive                           0.297407  ...          -0.118428
# affective                               0.260019  ...          -0.176520
# social                                  0.297840  ...           0.084248
# score                                   0.046734  ...           0.005040
#
#                                peer_learning  help_seeking    memory  \
# intrinsic                           0.127518      0.190901  0.178922
# extrinsic                           0.135747      0.305975  0.078186
# task_value                          0.149104      0.305511  0.170880
# control_beliefs                     0.170635      0.310995  0.062442
# self_efficacy                       0.116029      0.210076  0.104455
# test_anxiety                        0.011002      0.077664  0.006449
# rehearsal                           0.090423      0.332098  0.193782
# elaboration                         0.076716      0.326828  0.244943
# organization                        0.181552      0.361303  0.176958
# critical_thinking                   0.119525      0.243916  0.287102
# metacognitive_self_regulation       0.112884      0.403490  0.153079
# time_environment                   -0.020078      0.244730  0.111319
# effort_regulation                  -0.139479      0.101273 -0.038778
# peer_learning                       1.000000      0.224453  0.186586
# help_seeking                        0.224453      1.000000  0.253482
# memory                              0.186586      0.253482  1.000000
# cognitive                           0.089615      0.229261  0.706743
# compensation                        0.032412      0.218849  0.538615
# metacognitive                       0.228863      0.265931  0.646550
# affective                           0.188657      0.255289  0.586025
# social                              0.106230      0.234628  0.499806
# score                              -0.078305      0.103907 -0.069890
#
#                                cognitive  compensation  metacognitive  \
# intrinsic                       0.203186      0.202098       0.193380
# extrinsic                       0.100385     -0.007547       0.132954
# task_value                      0.198680      0.209996       0.201662
# control_beliefs                 0.158872      0.094650       0.170433
# self_efficacy                   0.262210      0.298363       0.213835
# test_anxiety                   -0.084629     -0.130848       0.018024
# rehearsal                       0.213244      0.123616       0.182301
# elaboration                     0.292877      0.277655       0.197955
# organization                    0.132996      0.107355       0.166551
# critical_thinking               0.397161      0.381440       0.297407
# metacognitive_self_regulation   0.226780      0.205350       0.161430
# time_environment                0.161286      0.229086       0.079048
# effort_regulation               0.007689      0.086632      -0.118428
# peer_learning                   0.089615      0.032412       0.228863
# help_seeking                    0.229261      0.218849       0.265931
# memory                          0.706743      0.538615       0.646550
# cognitive                       1.000000      0.732330       0.757638
# compensation                    0.732330      1.000000       0.620841
# metacognitive                   0.757638      0.620841       1.000000
# affective                       0.554484      0.462787       0.742403
# social                          0.676076      0.639597       0.646597
# score                          -0.062287     -0.039462      -0.107385
#
#                                affective    social     score
# intrinsic                       0.143337  0.056255  0.161212
# extrinsic                       0.114244  0.155111  0.163326
# task_value                      0.172082  0.151105  0.215923
# control_beliefs                 0.117353  0.048228  0.191786
# self_efficacy                   0.142173  0.153123  0.302128
# test_anxiety                    0.070614  0.037174 -0.124452
# rehearsal                       0.215336  0.096930  0.080378
# elaboration                     0.178763  0.186503  0.121306
# organization                    0.155689  0.164880  0.053085
# critical_thinking               0.260019  0.297840  0.046734
# metacognitive_self_regulation   0.165158  0.262223  0.113404
# time_environment                0.113083  0.173743  0.121559
# effort_regulation              -0.176520  0.084248  0.005040
# peer_learning                   0.188657  0.106230 -0.078305
# help_seeking                    0.255289  0.234628  0.103907
# memory                          0.586025  0.499806 -0.069890
# cognitive                       0.554484  0.676076 -0.062287
# compensation                    0.462787  0.639597 -0.039462
# metacognitive                   0.742403  0.646597 -0.107385
# affective                       1.000000  0.500805 -0.107494
# social                          0.500805  1.000000 -0.113500
# score                          -0.107494 -0.113500  1.000000
#
# [22 rows x 22 columns]

# %%
ax = plt.axes()
ax.set_title('Questionario Correlation')

sns_plot = sns.heatmap(corr)

results_path = './data_plot/Questionario_Correlation.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')

# %% [markdown]
# ## viscode

# %%
viscode_pd = pd.read_csv('./data/viscode.csv')
#viscode_pd = viscode_pd.drop(['Unnamed: 0', 'userid', 'score', 'class' ], axis=1)

# %%
viscode_pd.nunique()
# Out:
# userid                     545
# code_copy                  376
# code_execution             451
# code_paste                 416
# code_speed                 515
# notebook_open              289
# tree_open                  117
# AssertionError               2
# AttributeError              41
# AxisError                    2
# ConversionError              3
# DataError                    2
# EmptyDataError               7
# Exception                    3
# FeatureNotFound              2
# FileNotFoundError           13
# HTTPError                    3
# ImportError                  4
# IndentationError            65
# IndexError                  29
# IndexingError                2
# InvalidURL                   2
# KeyError                    41
# KeyboardInterrupt           25
# ModuleNotFoundError         11
# NameError                   76
# OSError                      2
# OverflowError                2
# ParserError                 11
# RecursionError              10
# RuntimeError                 6
# SelectorSyntaxError          2
# SpecificationError           2
# StopIteration                3
# SyntaxError                183
# TabError                    16
# TclError                     2
# TypeError                   65
# UFuncTypeError               2
# UnboundLocalError           13
# UndefinedVariableError       2
# ValueError                  34
# WebDriverException           2
# XLRDError                    2
# ZeroDivisionError           11
# codeLength                 517
# Viscode-login_times        318
# Viscode-execute_times      500
# Viscode-open_file_times    289
# Viscode-success_run        502
# Viscode-failed_run         267
# Viscode-error_types         16
# Viscode-spent_time         539
# dtype: int64

# %%
plt.figure(figsize=(20, 3))



plt.subplot(1, 3, 1)
viscode_pd[['code_copy', 'code_execution', 'code_paste', 'notebook_open', 'tree_open']].boxplot()

plt.xticks(rotation=90)


plt.subplot(1, 3, 2)
viscode_pd[['Viscode-login_times', 'Viscode-execute_times', 'Viscode-open_file_times', 'Viscode-success_run', 'Viscode-failed_run', 'Viscode-error_types', 'Viscode-spent_time']].boxplot()
plt.xticks(rotation=90)

plt.title('VisCode Features Distribution')

# plt.subplot(1, 3, 3)
# viscode_pd[['code_speed', 'codeLength' ]].boxplot()
# plt.xticks(rotation=90)

plt.subplot(1, 3, 3)
viscode_pd.drop(['codeLength','code_copy', 'code_execution', 'code_paste', 'code_speed', 'notebook_open', 'tree_open', 'Viscode-login_times', 'Viscode-execute_times', 'Viscode-open_file_times', 'Viscode-success_run', 'Viscode-failed_run', 'Viscode-error_types', 'Viscode-spent_time'], axis=1).boxplot() # 
plt.xticks(rotation=90)




results_path = './data_plot/VisCode_Features_Distribution.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15, 5))
viscode_pd[['IndentationError', 'NameError', 'SyntaxError', 'TypeError', 'AttributeError', 'KeyError']].boxplot()
# Out:
# <Axes: >

# %%
viscode_pd = pd.read_csv('./data/viscode.csv')
#viscode_pd = viscode_pd.drop(['Unnamed: 0', 'class', 'score'], axis =1)
viscode_pd
# Out:
#                                userid  code_copy  code_execution  code_paste  \
# 0    01291c313aef72b9786046bd7ce4cfca        584            1398         714
# 1    019acd030e0cdf674dda03e2a8ca4369        507             887         670
# 2    01ea38c4c3cc5fba869732fc641ca884        176             582         264
# 3    023c88ec58c8cf0abcfbcea4166793ad         89             588         137
# 4    02d679ad650962b6ae8bf8adbeeb33c1         69             545         150
# ..                                ...        ...             ...         ...
# 540  fde0bceed4e87f770bbb3e07bec22d05       1102            1275        1421
# 541  fe893f4359d6a6a550d109199d5f10f4        106            1044         129
# 542  ff352cc412dda02baf83e6c095f81622        394            1270         520
# 543  ff6a83db7cd1e89e7f401de25e5edcb7         10               9          20
# 544  ffc7749aa8337fadddcbd42d9cf6e5ec        284             820         358
#
#      code_speed  notebook_open  tree_open  AssertionError  AttributeError  \
# 0          5181            439         70             0.0             8.0
# 1          4827            254         70             0.0             8.0
# 2          1521             73         35             0.0             7.0
# 3          1563             79         44             0.0             8.0
# 4          1119             41         24             0.0             2.0
# ..          ...            ...        ...             ...             ...
# 540        5092            308         83             0.0             7.0
# 541        2840            125         50             0.0            29.0
# 542        4938            329        118             0.0             2.0
# 543          54              4          2             0.0             0.0
# 544        3362            191         33             0.0             5.0
#
#      AxisError  ...  XLRDError  ZeroDivisionError  codeLength  \
# 0          0.0  ...        0.0                0.0      4710.0
# 1          0.0  ...        0.0                0.0      1368.0
# 2          0.0  ...        0.0                0.0      3543.0
# 3          0.0  ...        0.0                0.0      3472.0
# 4          0.0  ...        0.0                0.0      1228.0
# ..         ...  ...        ...                ...         ...
# 540        0.0  ...        0.0                0.0      5206.0
# 541        0.0  ...        0.0                0.0      3714.0
# 542        0.0  ...        0.0                0.0      3934.0
# 543        0.0  ...        0.0                0.0       194.0
# 544        0.0  ...        0.0                0.0       982.0
#
#      Viscode-login_times  Viscode-execute_times  Viscode-open_file_times  \
# 0                    509                   3205                    439.0
# 1                    324                   2388                    254.0
# 2                    108                   1130                     73.0
# 3                    123                    937                     79.0
# 4                     65                    829                     41.0
# ..                   ...                    ...                      ...
# 540                  391                   4189                    308.0
# 541                  175                   1454                    125.0
# 542                  447                   2631                    329.0
# 543                    6                     45                      4.0
# 544                  224                   1686                    191.0
#
#      Viscode-success_run  Viscode-failed_run  Viscode-error_types  \
# 0                   2950               255.0                 10.0
# 1                   2256               132.0                  7.0
# 2                   1020               110.0                  8.0
# 3                    811               126.0                  6.0
# 4                    701               128.0                  7.0
# ..                   ...                 ...                  ...
# 540                 4048               141.0                  9.0
# 541                 1090               364.0                 11.0
# 542                 2399               232.0                  9.0
# 543                   43                 2.0                  1.0
# 544                 1573               113.0                  7.0
#
#          Viscode-spent_time
# 0    0 days 02:28:28.302167
# 1    0 days 01:24:59.160120
# 2    0 days 00:50:32.025803
# 3    0 days 00:54:26.187369
# 4    0 days 01:06:30.302228
# ..                      ...
# 540  0 days 02:13:10.995293
# 541  0 days 01:39:59.864313
# 542  0 days 02:07:27.617555
# 543  0 days 00:00:25.883548
# 544  0 days 01:29:48.690987
#
# [545 rows x 53 columns]

# %%
merge_pd = pd.merge(viscode_pd, score_pd, on='userid', how = 'outer')
merge_pd = merge_pd.drop( 'userid', axis =1)
merge_pd
# Out:
#      code_copy  code_execution  code_paste  code_speed  notebook_open  \
# 0        584.0          1398.0       714.0      5181.0          439.0
# 1        507.0           887.0       670.0      4827.0          254.0
# 2        176.0           582.0       264.0      1521.0           73.0
# 3         89.0           588.0       137.0      1563.0           79.0
# 4         69.0           545.0       150.0      1119.0           41.0
# ..         ...             ...         ...         ...            ...
# 556        NaN             NaN         NaN         NaN            NaN
# 557        NaN             NaN         NaN         NaN            NaN
# 558        NaN             NaN         NaN         NaN            NaN
# 559        NaN             NaN         NaN         NaN            NaN
# 560        NaN             NaN         NaN         NaN            NaN
#
#      tree_open  AssertionError  AttributeError  AxisError  ConversionError  \
# 0         70.0             0.0             8.0        0.0              0.0
# 1         70.0             0.0             8.0        0.0              0.0
# 2         35.0             0.0             7.0        0.0              0.0
# 3         44.0             0.0             8.0        0.0              0.0
# 4         24.0             0.0             2.0        0.0              0.0
# ..         ...             ...             ...        ...              ...
# 556        NaN             NaN             NaN        NaN              NaN
# 557        NaN             NaN             NaN        NaN              NaN
# 558        NaN             NaN             NaN        NaN              NaN
# 559        NaN             NaN             NaN        NaN              NaN
# 560        NaN             NaN             NaN        NaN              NaN
#
#      ...  codeLength  Viscode-login_times  Viscode-execute_times  \
# 0    ...      4710.0                509.0                 3205.0
# 1    ...      1368.0                324.0                 2388.0
# 2    ...      3543.0                108.0                 1130.0
# 3    ...      3472.0                123.0                  937.0
# 4    ...      1228.0                 65.0                  829.0
# ..   ...         ...                  ...                    ...
# 556  ...         NaN                  NaN                    NaN
# 557  ...         NaN                  NaN                    NaN
# 558  ...         NaN                  NaN                    NaN
# 559  ...         NaN                  NaN                    NaN
# 560  ...         NaN                  NaN                    NaN
#
#      Viscode-open_file_times  Viscode-success_run  Viscode-failed_run  \
# 0                      439.0               2950.0               255.0
# 1                      254.0               2256.0               132.0
# 2                       73.0               1020.0               110.0
# 3                       79.0                811.0               126.0
# 4                       41.0                701.0               128.0
# ..                       ...                  ...                 ...
# 556                      NaN                  NaN                 NaN
# 557                      NaN                  NaN                 NaN
# 558                      NaN                  NaN                 NaN
# 559                      NaN                  NaN                 NaN
# 560                      NaN                  NaN                 NaN
#
#      Viscode-error_types      Viscode-spent_time  score  class
# 0                   10.0  0 days 02:28:28.302167   91.0      j
# 1                    7.0  0 days 01:24:59.160120   70.0      h
# 2                    8.0  0 days 00:50:32.025803   80.0      a
# 3                    6.0  0 days 00:54:26.187369   90.0      a
# 4                    7.0  0 days 01:06:30.302228   56.0      c
# ..                   ...                     ...    ...    ...
# 556                  NaN                     NaN   94.0      i
# 557                  NaN                     NaN   88.0      i
# 558                  NaN                     NaN   64.0      i
# 559                  NaN                     NaN   75.0      i
# 560                  NaN                     NaN    0.0      j
#
# [561 rows x 54 columns]

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
ax = plt.axes()
ax.set_title('VisCode Correlation')

sns_plot = sns.heatmap(corr)

results_path = './data_plot/VisCode_Correlation.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')

# %% [markdown]
# ## bookroll

# %%
br_pd = pd.read_csv('./data/br.csv')

# %%
#br_pd = br_pd.drop(['ADD_RECOMMENDATION', 'CLOSE_RECOMMENDATION', 'OPEN_RECOMMENDATION', 'LINK_CLICK', 'REGIST CONTENTS'], axis=1)
#br_pd = br_pd.drop(['ADD_RECOMMENDATION', 'CLOSE_RECOMMENDATION', 'OPEN_RECOMMENDATION', 'LINK_CLICK', 'REGIST CONTENTS'], axis=1)
br_pd = br_pd.drop(['CLOSE_RECOMMENDATION', 'OPEN_RECOMMENDATION', 'LINK_CLICK', 'REGIST CONTENTS'], axis=1)
br_pd
# Out:
#                                userid  ADD BOOKMARK  ADD MARKER  ADD MEMO  \
# 0    01291c313aef72b9786046bd7ce4cfca             9         144        12
# 1    019acd030e0cdf674dda03e2a8ca4369             1          81        15
# 2    01ea38c4c3cc5fba869732fc641ca884             7         354        36
# 3    023c88ec58c8cf0abcfbcea4166793ad             1          61        25
# 4    02d679ad650962b6ae8bf8adbeeb33c1             4         188        28
# ..                                ...           ...         ...       ...
# 509  fda96a011b9b53ba6aa39fa978140bdc            39         490        44
# 510  fde0bceed4e87f770bbb3e07bec22d05             0           0         8
# 511  ff352cc412dda02baf83e6c095f81622             0         186        19
# 512  ff6a83db7cd1e89e7f401de25e5edcb7             1           0         0
# 513  ffc7749aa8337fadddcbd42d9cf6e5ec             0          70        13
#
#      ADD_HW_MEMO  BOOKMARK_JUMP  CHANGE MEMO  CLEAR_HW_MEMO  CLOSE  \
# 0             63             64           96              2     80
# 1              0              0           14              0     95
# 2              1              2           22              1    211
# 3              0              0            9              0    290
# 4              8              4           25              0     38
# ..           ...            ...          ...            ...    ...
# 509            2              0          144              0    240
# 510            0              0           33              0     60
# 511           16              0           19              6     78
# 512            0              0            0              0      9
# 513           20              0           13              2     46
#
#      DELETE BOOKMARK  ...  NEXT  NOTGETIT  OPEN  PAGE_JUMP  PREV  QUIZ_ANSWER  \
# 0                  2  ...  2724         0   111        237   889            0
# 1                  0  ...  3321         2   159        109  1584            0
# 2                  4  ...  2209         1   256         67   750            0
# 3                  1  ...  3707         1   325          7  1275            0
# 4                  2  ...  1413         0   138         40   788            0
# ..               ...  ...   ...       ...   ...        ...   ...          ...
# 509                2  ...  3834         1   343         20  1518            0
# 510                0  ...  2105         1   126        188   514            0
# 511                0  ...  2733         0   159        169  1034            0
# 512                0  ...   125         0     9          0     0            0
# 513                0  ...  1593         0    69         26   907            0
#
#      QUIZ_ANSWER_CORRECT  SEARCH  SEARCH_JUMP  UNDO_HW_MEMO
# 0                      0       0            0            65
# 1                      0       0            0             0
# 2                      0       1            0             2
# 3                      0       0            0             0
# 4                      0       0            0             0
# ..                   ...     ...          ...           ...
# 509                    0       0            0             2
# 510                    0       0            0             0
# 511                    0       0            0             1
# 512                    0       0            0             0
# 513                    0       0            0             3
#
# [514 rows x 24 columns]

# %%
plt.figure(figsize=(20, 3))


plt.subplot(1, 3, 1)
br_pd.drop(['NEXT', 'PREV','ADD MARKER', 'OPEN', 'CLOSE', 'PAGE_JUMP', 'BOOKMARK_JUMP'], axis=1).boxplot() # 
plt.xticks(rotation=90)



plt.subplot(1, 3, 2)
br_pd[['BOOKMARK_JUMP', 'PAGE_JUMP', 'ADD MARKER', 'OPEN', 'CLOSE']].boxplot()
plt.xticks(rotation=90)

plt.title('BookRoll Features Distribution')


plt.subplot(1, 3, 3)
br_pd[['NEXT', 'PREV']].boxplot()
plt.xticks(rotation=90)


results_path = './data_plot/BookRoll_Features_Distribution.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
plt.show()

# %%
br_pd = pd.read_csv('./data/br.csv')
#br_pd = br_pd.drop(['Unnamed: 0', 'class', 'score', 'ADD_RECOMMENDATION', 'REGIST CONTENTS'], axis =1)
br_pd = br_pd.drop([ 'REGIST CONTENTS'], axis =1)
br_pd
# Out:
#                                userid  ADD BOOKMARK  ADD MARKER  ADD MEMO  \
# 0    01291c313aef72b9786046bd7ce4cfca             9         144        12
# 1    019acd030e0cdf674dda03e2a8ca4369             1          81        15
# 2    01ea38c4c3cc5fba869732fc641ca884             7         354        36
# 3    023c88ec58c8cf0abcfbcea4166793ad             1          61        25
# 4    02d679ad650962b6ae8bf8adbeeb33c1             4         188        28
# ..                                ...           ...         ...       ...
# 509  fda96a011b9b53ba6aa39fa978140bdc            39         490        44
# 510  fde0bceed4e87f770bbb3e07bec22d05             0           0         8
# 511  ff352cc412dda02baf83e6c095f81622             0         186        19
# 512  ff6a83db7cd1e89e7f401de25e5edcb7             1           0         0
# 513  ffc7749aa8337fadddcbd42d9cf6e5ec             0          70        13
#
#      ADD_HW_MEMO  BOOKMARK_JUMP  CHANGE MEMO  CLEAR_HW_MEMO  CLOSE  \
# 0             63             64           96              2     80
# 1              0              0           14              0     95
# 2              1              2           22              1    211
# 3              0              0            9              0    290
# 4              8              4           25              0     38
# ..           ...            ...          ...            ...    ...
# 509            2              0          144              0    240
# 510            0              0           33              0     60
# 511           16              0           19              6     78
# 512            0              0            0              0      9
# 513           20              0           13              2     46
#
#      CLOSE_RECOMMENDATION  ...  NOTGETIT  OPEN  OPEN_RECOMMENDATION  \
# 0                       0  ...         0   111                    0
# 1                       0  ...         2   159                    0
# 2                       1  ...         1   256                    0
# 3                       0  ...         1   325                    0
# 4                       0  ...         0   138                    0
# ..                    ...  ...       ...   ...                  ...
# 509                     1  ...         1   343                    0
# 510                     0  ...         1   126                    0
# 511                     0  ...         0   159                    0
# 512                     0  ...         0     9                    0
# 513                     0  ...         0    69                    0
#
#      PAGE_JUMP  PREV  QUIZ_ANSWER  QUIZ_ANSWER_CORRECT  SEARCH  SEARCH_JUMP  \
# 0          237   889            0                    0       0            0
# 1          109  1584            0                    0       0            0
# 2           67   750            0                    0       1            0
# 3            7  1275            0                    0       0            0
# 4           40   788            0                    0       0            0
# ..         ...   ...          ...                  ...     ...          ...
# 509         20  1518            0                    0       0            0
# 510        188   514            0                    0       0            0
# 511        169  1034            0                    0       0            0
# 512          0     0            0                    0       0            0
# 513         26   907            0                    0       0            0
#
#      UNDO_HW_MEMO
# 0              65
# 1               0
# 2               2
# 3               0
# 4               0
# ..            ...
# 509             2
# 510             0
# 511             1
# 512             0
# 513             3
#
# [514 rows x 27 columns]

# %%
merge_pd = pd.merge(br_pd, score_pd, on='userid', how = 'outer')
merge_pd = merge_pd.drop( 'userid', axis =1)
merge_pd
# Out:
#      ADD BOOKMARK  ADD MARKER  ADD MEMO  ADD_HW_MEMO  BOOKMARK_JUMP  \
# 0             9.0       144.0      12.0         63.0           64.0
# 1             1.0        81.0      15.0          0.0            0.0
# 2             7.0       354.0      36.0          1.0            2.0
# 3             1.0        61.0      25.0          0.0            0.0
# 4             4.0       188.0      28.0          8.0            4.0
# ..            ...         ...       ...          ...            ...
# 564           NaN         NaN       NaN          NaN            NaN
# 565           NaN         NaN       NaN          NaN            NaN
# 566           NaN         NaN       NaN          NaN            NaN
# 567           NaN         NaN       NaN          NaN            NaN
# 568           NaN         NaN       NaN          NaN            NaN
#
#      CHANGE MEMO  CLEAR_HW_MEMO  CLOSE  CLOSE_RECOMMENDATION  DELETE BOOKMARK  \
# 0           96.0            2.0   80.0                   0.0              2.0
# 1           14.0            0.0   95.0                   0.0              0.0
# 2           22.0            1.0  211.0                   1.0              4.0
# 3            9.0            0.0  290.0                   0.0              1.0
# 4           25.0            0.0   38.0                   0.0              2.0
# ..           ...            ...    ...                   ...              ...
# 564          NaN            NaN    NaN                   NaN              NaN
# 565          NaN            NaN    NaN                   NaN              NaN
# 566          NaN            NaN    NaN                   NaN              NaN
# 567          NaN            NaN    NaN                   NaN              NaN
# 568          NaN            NaN    NaN                   NaN              NaN
#
#      ...  OPEN_RECOMMENDATION  PAGE_JUMP    PREV  QUIZ_ANSWER  \
# 0    ...                  0.0      237.0   889.0          0.0
# 1    ...                  0.0      109.0  1584.0          0.0
# 2    ...                  0.0       67.0   750.0          0.0
# 3    ...                  0.0        7.0  1275.0          0.0
# 4    ...                  0.0       40.0   788.0          0.0
# ..   ...                  ...        ...     ...          ...
# 564  ...                  NaN        NaN     NaN          NaN
# 565  ...                  NaN        NaN     NaN          NaN
# 566  ...                  NaN        NaN     NaN          NaN
# 567  ...                  NaN        NaN     NaN          NaN
# 568  ...                  NaN        NaN     NaN          NaN
#
#      QUIZ_ANSWER_CORRECT  SEARCH  SEARCH_JUMP  UNDO_HW_MEMO  score  class
# 0                    0.0     0.0          0.0          65.0   91.0      j
# 1                    0.0     0.0          0.0           0.0   70.0      h
# 2                    0.0     1.0          0.0           2.0   80.0      a
# 3                    0.0     0.0          0.0           0.0   90.0      a
# 4                    0.0     0.0          0.0           0.0   56.0      c
# ..                   ...     ...          ...           ...    ...    ...
# 564                  NaN     NaN          NaN           NaN   81.0      i
# 565                  NaN     NaN          NaN           NaN   91.0      i
# 566                  NaN     NaN          NaN           NaN   97.0      i
# 567                  NaN     NaN          NaN           NaN   75.0      i
# 568                  NaN     NaN          NaN           NaN   89.0      i
#
# [569 rows x 28 columns]

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
ax = plt.axes()
ax.set_title('BookRoll Correlation')

sns_plot = sns.heatmap(corr)

results_path = './data_plot/BookRoll_Correlation.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
