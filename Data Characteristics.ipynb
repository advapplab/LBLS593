# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      -------------------------------------- 293.3/293.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.4)
# Collecting matplotlib!=3.6.1,>=3.1
#   Downloading matplotlib-3.7.1-cp310-cp310-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.5)
# Requirement already satisfied: six>=1.5 in c:\users\mimo\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: matplotlib, seaborn
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.1
#     Uninstalling matplotlib-3.6.1:
#       Successfully uninstalled matplotlib-3.6.1
# Successfully installed matplotlib-3.7.1 seaborn-0.12.2
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
br_pd = pd.read_csv('./data/br.csv')
viscode_pd = pd.read_csv('./data/viscode.csv')
score_pd = pd.read_csv('./data/score.csv')
srl_s_pd = pd.read_csv('./data/srl_strategy.csv')
srl_m_pd = pd.read_csv('./data/srl_motivation.csv')
sill_pd = pd.read_csv('./data/sill.csv')

# %% [markdown]
# # Data Characteristics

# %% [markdown]
# ## score

# %%
score_pd.nunique()
# Out:
# userid    593
# score      77
# class      12
# dtype: int64

# %%
plt.figure(figsize=(5, 2))
score_pd['score'].hist(bins=10)
plt.title('Score Distribution of All Student')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.savefig('./data_plot/score')
plt.show()

# %%
plt.figure(figsize=(5, 2))
score_pd[score_pd['class']=='h']['score'].hist(bins=10)

plt.title('Score Distribution of Class H(Non-EMI)')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.show()

# %%
plt.figure(figsize=(5, 2))
score_pd[score_pd['class']=='i']['score'].hist(bins=10)

plt.title('Score Distribution of Class I(EMI)')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.show()

# %%
plt.figure(figsize=(5, 2))
score_pd[score_pd['class']=='j']['score'].hist(bins=10)

plt.title('Score Distribution of Class I(EMI)')
plt.ylabel('Numbers')
plt.xlabel('Score')
plt.show()

# %%
def Plot_Score():
    classID = 'abcdefghij'
    for cid in classID :
        print(cid)
        plt.figure(figsize=(5, 2))
        score_pd[score_pd['class']==cid]['score'].hist(bins=10)

        plt.title('Score Distribution of Class ' + cid )
        plt.ylabel('Numbers')
        plt.xlabel('Score')
        save_path = './data_plot/score_'+cid
        plt.savefig(save_path)
        plt.show()
Plot_Score()
# Out:
# a
# b
# c
# d
# e
# f
# g
# h
# i
# j

# %%
score_pd
# Out:
#                                userid  score class
# 0    faceedc2fdf78a0f24b2e469c8072881     68     a
# 1    3017f8db51adce97836bfbd2a5e76bc4     29     a
# 2    fcd714c799381d83a55d85fc8813aaf2     44     a
# 3    822f678c2e95794c527b1f854bd35006     74     a
# 4    52a83b516a01c8cefdb16bd3acb4b844     76     a
# ..                                ...    ...   ...
# 588  9bd618eaed116460daea6aba18c01d6a     91     l
# 589  d7f459f4c30a2dcfa42d2b0375f65ea3     88     l
# 590  56e396be6a1330dac4f422b388404b1a     91     l
# 591  533e00673b20fee7cb33dfb7290731a9     95     l
# 592  50b8b51ed864f6b0b7eb5d173b6f2d25     87     l
#
# [593 rows x 3 columns]

# %% [markdown]
# # Data Statistics

# %% [markdown]
# # SILL

# %%
sill_pd = pd.read_csv('./data/sill.csv')
sill_pd
# Out:
#                                userid  s_1  s_2  s_3  s_4  s_5  s_6  s_7  s_8  \
# 0    b1dfc5c6ec04d46d1823c5fa972ad320    5    5    5    5    1    1    5    1
# 1    4e3519d7eafbfccdae231756fcf2ce9c    3    3    3    3    3    3    3    3
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698    5    5    5    4    5    5    5    5
# 3    379bbc4c2c728db0a249e8c4e6b621af    3    3    3    3    3    3    5    3
# 4    a92f1708363527a34d93b0bc7840262c    3    4    3    3    2    2    4    4
# ..                                ...  ...  ...  ...  ...  ...  ...  ...  ...
# 287  7caa5e63a94c013842534b6ac9abc8c5    4    3    4    3    3    4    3    3
# 288  65ea88037d2e504521081a28edcffa68    2    3    2    3    3    2    2    2
# 289  2abeed29705e8047bd0a7af55bbda567    2    2    3    2    2    3    3    2
# 290  a0332283e1713ef0d11504ad72bd93ee    2    2    2    2    2    2    2    2
# 291  1a79f93f5657aafdd595150d86125505    3    2    4    3    3    3    2    4
#
#      s_9  ...  s_39  s_40  s_41  s_42  s_43  s_44  s_45  s_46  s_47  s_48
# 0      5  ...     5     1     1     5     5     5     1     1     1     5
# 1      3  ...     4     4     3     4     4     4     3     3     4     3
# 2      5  ...     5     5     4     5     5     4     3     5     5     4
# 3      5  ...     5     1     4     5     5     5     5     5     5     5
# 4      3  ...     4     3     3     3     4     3     2     3     2     3
# ..   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 287    4  ...     3     2     1     2     3     3     3     3     3     4
# 288    2  ...     3     3     1     2     3     2     2     2     3     2
# 289    2  ...     3     3     1     2     3     3     1     2     2     3
# 290    1  ...     1     1     1     1     2     2     1     1     1     1
# 291    3  ...     2     3     1     1     4     3     2     2     2     3
#
# [292 rows x 49 columns]

# %%
# Calculate Standard Deviation & Delete the data which sd=0 
question_list = sill_pd.columns[1:49]
sill_pd['sd'] = sill_pd[question_list].std(axis=1)
keep_list = sill_pd['sd'] > 0
sill_pd = sill_pd[keep_list]

'''
    Merge by Category 
    ---------------------------
    category      : Question number
    ---------------------------
    memory        : 1-8 (8)
    cognitive     : 9-21 (13)
    compensation  : 22-27 (6)
    metacognitive : 28-36 (9)
    affective     : 37-42 (6)
    social        : 43-48 (6)
'''

memory_list = sill_pd.columns[1:9]
cognitive_list = sill_pd.columns[9:22]
compensation_list = sill_pd.columns[22:28]
metacognitive_list = sill_pd.columns[28:37]
affective_list = sill_pd.columns[37:43]
social_list = sill_pd.columns[43:49]

sill_pd['memory'] = sill_pd[memory_list].sum(axis=1)/8
sill_pd['cognitive'] = sill_pd[cognitive_list].sum(axis=1)/13
sill_pd['compensation'] = sill_pd[compensation_list].sum(axis=1)/6
sill_pd['metacognitive'] = sill_pd[metacognitive_list].sum(axis=1)/9
sill_pd['affective'] = sill_pd[affective_list].sum(axis=1)/6
sill_pd['social'] = sill_pd[social_list].sum(axis=1)/6

# keep data with same category
keep_list = ['userid', 'memory', 'cognitive', 'compensation', 'metacognitive', 'affective', 'social']
sill_pd = sill_pd[keep_list]
sill_pd = sill_pd.reset_index()
sill_pd = sill_pd.drop('index', axis=1)
sill_pd
# Out:
# /tmp/ipykernel_3983012/1379482121.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['memory'] = sill_pd[memory_list].sum(axis=1)/8
# /tmp/ipykernel_3983012/1379482121.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['cognitive'] = sill_pd[cognitive_list].sum(axis=1)/13
# /tmp/ipykernel_3983012/1379482121.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['compensation'] = sill_pd[compensation_list].sum(axis=1)/6
# /tmp/ipykernel_3983012/1379482121.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['metacognitive'] = sill_pd[metacognitive_list].sum(axis=1)/9
# /tmp/ipykernel_3983012/1379482121.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['affective'] = sill_pd[affective_list].sum(axis=1)/6
# /tmp/ipykernel_3983012/1379482121.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sill_pd['social'] = sill_pd[social_list].sum(axis=1)/6
#                                userid  memory  cognitive  compensation  \
# 0    b1dfc5c6ec04d46d1823c5fa972ad320   3.500   4.307692      3.333333
# 1    4e3519d7eafbfccdae231756fcf2ce9c   3.000   3.000000      2.833333
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698   4.875   4.846154      4.500000
# 3    379bbc4c2c728db0a249e8c4e6b621af   3.250   5.000000      4.666667
# 4    a92f1708363527a34d93b0bc7840262c   3.125   3.538462      3.833333
# ..                                ...     ...        ...           ...
# 282  7caa5e63a94c013842534b6ac9abc8c5   3.375   3.076923      3.500000
# 283  65ea88037d2e504521081a28edcffa68   2.375   2.307692      2.666667
# 284  2abeed29705e8047bd0a7af55bbda567   2.375   2.538462      2.833333
# 285  a0332283e1713ef0d11504ad72bd93ee   2.000   1.153846      1.500000
# 286  1a79f93f5657aafdd595150d86125505   3.000   3.000000      3.333333
#
#      metacognitive  affective    social
# 0         5.000000   3.500000  3.000000
# 1         3.000000   3.833333  3.500000
# 2         4.888889   4.500000  4.333333
# 3         4.666667   3.833333  5.000000
# 4         3.888889   3.500000  2.833333
# ..             ...        ...       ...
# 282       3.111111   2.500000  3.166667
# 283       2.000000   2.333333  2.333333
# 284       2.222222   2.500000  2.333333
# 285       1.000000   1.000000  1.333333
# 286       3.000000   2.166667  2.666667
#
# [287 rows x 7 columns]

# %%
data = sill_pd.drop('userid', axis=1)
plt.figure(figsize=(10, 3))
data.boxplot()
plt.title('SILL Questionario')
plt.savefig('./data_plot/sill')
plt.show()

# %%
merged_pd = pd.merge(sill_pd, score_pd, on='userid', how='inner')
merged_pd
# Out:
#                                userid  memory  cognitive  compensation  \
# 0    b1dfc5c6ec04d46d1823c5fa972ad320   3.500   4.307692      3.333333
# 1    4e3519d7eafbfccdae231756fcf2ce9c   3.000   3.000000      2.833333
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698   4.875   4.846154      4.500000
# 3    379bbc4c2c728db0a249e8c4e6b621af   3.250   5.000000      4.666667
# 4    a92f1708363527a34d93b0bc7840262c   3.125   3.538462      3.833333
# ..                                ...     ...        ...           ...
# 281  7caa5e63a94c013842534b6ac9abc8c5   3.375   3.076923      3.500000
# 282  65ea88037d2e504521081a28edcffa68   2.375   2.307692      2.666667
# 283  2abeed29705e8047bd0a7af55bbda567   2.375   2.538462      2.833333
# 284  a0332283e1713ef0d11504ad72bd93ee   2.000   1.153846      1.500000
# 285  1a79f93f5657aafdd595150d86125505   3.000   3.000000      3.333333
#
#      metacognitive  affective    social  score class
# 0         5.000000   3.500000  3.000000     90     b
# 1         3.000000   3.833333  3.500000     72     b
# 2         4.888889   4.500000  4.333333     98     b
# 3         4.666667   3.833333  5.000000     94     b
# 4         3.888889   3.500000  2.833333     78     b
# ..             ...        ...       ...    ...   ...
# 281       3.111111   2.500000  3.166667     97     k
# 282       2.000000   2.333333  2.333333     97     k
# 283       2.222222   2.500000  2.333333     86     k
# 284       1.000000   1.000000  1.333333     75     k
# 285       3.000000   2.166667  2.666667     92     k
#
# [286 rows x 9 columns]

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b0448_row0_col0, #T_b0448_row1_col1, #T_b0448_row2_col2, #T_b0448_row3_col3, #T_b0448_row4_col4, #T_b0448_row5_col5, #T_b0448_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b0448_row0_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_b0448_row0_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_b0448_row0_col3, #T_b0448_row3_col5, #T_b0448_row5_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b0448_row0_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_b0448_row0_col5, #T_b0448_row4_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b0448_row0_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b0448_row1_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_b0448_row1_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_b0448_row1_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_b0448_row1_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_b0448_row1_col5 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_b0448_row1_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_b0448_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b0448_row2_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_b0448_row2_col3 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_b0448_row2_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b0448_row2_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_b0448_row2_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b0448_row3_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_b0448_row3_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_b0448_row3_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_b0448_row3_col4, #T_b0448_row4_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_b0448_row3_col6, #T_b0448_row4_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b0448_row4_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_b0448_row4_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_b0448_row4_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_b0448_row5_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_b0448_row5_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_b0448_row5_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_b0448_row5_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_b0448_row5_col6, #T_b0448_row6_col0, #T_b0448_row6_col1, #T_b0448_row6_col2, #T_b0448_row6_col3, #T_b0448_row6_col4, #T_b0448_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0448">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0448_level0_col0" class="col_heading level0 col0" >memory</th>
#       <th id="T_b0448_level0_col1" class="col_heading level0 col1" >cognitive</th>
#       <th id="T_b0448_level0_col2" class="col_heading level0 col2" >compensation</th>
#       <th id="T_b0448_level0_col3" class="col_heading level0 col3" >metacognitive</th>
#       <th id="T_b0448_level0_col4" class="col_heading level0 col4" >affective</th>
#       <th id="T_b0448_level0_col5" class="col_heading level0 col5" >social</th>
#       <th id="T_b0448_level0_col6" class="col_heading level0 col6" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0448_level0_row0" class="row_heading level0 row0" >memory</th>
#       <td id="T_b0448_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b0448_row0_col1" class="data row0 col1" >0.704032</td>
#       <td id="T_b0448_row0_col2" class="data row0 col2" >0.543690</td>
#       <td id="T_b0448_row0_col3" class="data row0 col3" >0.648986</td>
#       <td id="T_b0448_row0_col4" class="data row0 col4" >0.587553</td>
#       <td id="T_b0448_row0_col5" class="data row0 col5" >0.500364</td>
#       <td id="T_b0448_row0_col6" class="data row0 col6" >-0.069890</td>
#     </tr>
#     <tr>
#       <th id="T_b0448_level0_row1" class="row_heading level0 row1" >cognitive</th>
#       <td id="T_b0448_row1_col0" class="data row1 col0" >0.704032</td>
#       <td id="T_b0448_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b0448_row1_col2" class="data row1 col2" >0.737660</td>
#       <td id="T_b0448_row1_col3" class="data row1 col3" >0.760102</td>
#       <td id="T_b0448_row1_col4" class="data row1 col4" >0.555527</td>
#       <td id="T_b0448_row1_col5" class="data row1 col5" >0.677194</td>
#       <td id="T_b0448_row1_col6" class="data row1 col6" >-0.062287</td>
#     </tr>
#     <tr>
#       <th id="T_b0448_level0_row2" class="row_heading level0 row2" >compensation</th>
#       <td id="T_b0448_row2_col0" class="data row2 col0" >0.543690</td>
#       <td id="T_b0448_row2_col1" class="data row2 col1" >0.737660</td>
#       <td id="T_b0448_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b0448_row2_col3" class="data row2 col3" >0.621202</td>
#       <td id="T_b0448_row2_col4" class="data row2 col4" >0.463279</td>
#       <td id="T_b0448_row2_col5" class="data row2 col5" >0.640341</td>
#       <td id="T_b0448_row2_col6" class="data row2 col6" >-0.039462</td>
#     </tr>
#     <tr>
#       <th id="T_b0448_level0_row3" class="row_heading level0 row3" >metacognitive</th>
#       <td id="T_b0448_row3_col0" class="data row3 col0" >0.648986</td>
#       <td id="T_b0448_row3_col1" class="data row3 col1" >0.760102</td>
#       <td id="T_b0448_row3_col2" class="data row3 col2" >0.621202</td>
#       <td id="T_b0448_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b0448_row3_col4" class="data row3 col4" >0.742385</td>
#       <td id="T_b0448_row3_col5" class="data row3 col5" >0.646581</td>
#       <td id="T_b0448_row3_col6" class="data row3 col6" >-0.107385</td>
#     </tr>
#     <tr>
#       <th id="T_b0448_level0_row4" class="row_heading level0 row4" >affective</th>
#       <td id="T_b0448_row4_col0" class="data row4 col0" >0.587553</td>
#       <td id="T_b0448_row4_col1" class="data row4 col1" >0.555527</td>
#       <td id="T_b0448_row4_col2" class="data row4 col2" >0.463279</td>
#       <td id="T_b0448_row4_col3" class="data row4 col3" >0.742385</td>
#       <td id="T_b0448_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b0448_row4_col5" class="data row4 col5" >0.500659</td>
#       <td id="T_b0448_row4_col6" class="data row4 col6" >-0.107494</td>
#     </tr>
#     <tr>
#       <th id="T_b0448_level0_row5" class="row_heading level0 row5" >social</th>
#       <td id="T_b0448_row5_col0" class="data row5 col0" >0.500364</td>
#       <td id="T_b0448_row5_col1" class="data row5 col1" >0.677194</td>
#       <td id="T_b0448_row5_col2" class="data row5 col2" >0.640341</td>
#       <td id="T_b0448_row5_col3" class="data row5 col3" >0.646581</td>
#       <td id="T_b0448_row5_col4" class="data row5 col4" >0.500659</td>
#       <td id="T_b0448_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b0448_row5_col6" class="data row5 col6" >-0.113500</td>
#     </tr>
#     <tr>
#       <th id="T_b0448_level0_row6" class="row_heading level0 row6" >score</th>
#       <td id="T_b0448_row6_col0" class="data row6 col0" >-0.069890</td>
#       <td id="T_b0448_row6_col1" class="data row6 col1" >-0.062287</td>
#       <td id="T_b0448_row6_col2" class="data row6 col2" >-0.039462</td>
#       <td id="T_b0448_row6_col3" class="data row6 col3" >-0.107385</td>
#       <td id="T_b0448_row6_col4" class="data row6 col4" >-0.107494</td>
#       <td id="T_b0448_row6_col5" class="data row6 col5" >-0.113500</td>
#       <td id="T_b0448_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                  memory  cognitive  compensation  metacognitive  affective  \
# memory         1.000000   0.704032      0.543690       0.648986   0.587553
# cognitive      0.704032   1.000000      0.737660       0.760102   0.555527
# compensation   0.543690   0.737660      1.000000       0.621202   0.463279
# metacognitive  0.648986   0.760102      0.621202       1.000000   0.742385
# affective      0.587553   0.555527      0.463279       0.742385   1.000000
# social         0.500364   0.677194      0.640341       0.646581   0.500659
# score         -0.069890  -0.062287     -0.039462      -0.107385  -0.107494
#
#                  social     score
# memory         0.500364 -0.069890
# cognitive      0.677194 -0.062287
# compensation   0.640341 -0.039462
# metacognitive  0.646581 -0.107385
# affective      0.500659 -0.107494
# social         1.000000 -0.113500
# score         -0.113500  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # SRL Motivation

# %%
srl_motivate_pd = pd.read_csv('./data/srl_motivation.csv')

# %%
# Calculate Standard Deviation & Delete the data which sd=0
question_list = srl_motivate_pd.columns[1:32]
srl_motivate_pd['sd'] = srl_motivate_pd[question_list].std(axis=1)
keep_list = srl_motivate_pd['sd'] > 0
srl_motivate_pd = srl_motivate_pd[keep_list]
srl_motivate_pd

'''
    Merge by Category 
    ---------------------------
    category      : Question number
    ---------------------------
    intrinsic       : 1-4 (4)
    extrinsic       : 5-8 (4)
    task_value      : 9-14 (6)
    control_beliefs : 15-18 (4)
    self_efficacy   : 19-26 (8)
    test_anxiety    : 27-31 (5)
'''

# classify data with same category
i = 1
intrinsic_goal_orientation = srl_motivate_pd.columns[i:i+4]
i = i + 4
extrinsic_goal_orientation = srl_motivate_pd.columns[i:i+4]
i = i + 4
task_value = srl_motivate_pd.columns[i:i+6]
i = i + 6
control_beliefs = srl_motivate_pd.columns[i:i+4]
i = i + 4
self_efficacy_and_performance = srl_motivate_pd.columns[i:i+8]
i = i + 8
test_anxiety = srl_motivate_pd.columns[i:i+5]


srl_motivate_pd['intrinsic'] = srl_motivate_pd[intrinsic_goal_orientation].sum(axis=1)/4
srl_motivate_pd['extrinsic'] = srl_motivate_pd[extrinsic_goal_orientation].sum(axis=1)/4
srl_motivate_pd['task_value'] = srl_motivate_pd[task_value].sum(axis=1)/6
srl_motivate_pd['control_beliefs'] = srl_motivate_pd[control_beliefs].sum(axis=1)/4
srl_motivate_pd['self_efficacy'] = srl_motivate_pd[self_efficacy_and_performance].sum(axis=1)/8
srl_motivate_pd['test_anxiety'] = srl_motivate_pd[test_anxiety].sum(axis=1)/5

# keep data with same category
keep_list = ['userid', 'intrinsic', 'extrinsic', 'task_value', 'control_beliefs', 'self_efficacy', 'test_anxiety']
srl_motivate_pd = srl_motivate_pd[keep_list]
srl_motivate_pd = srl_motivate_pd.reset_index()
srl_motivate_pd = srl_motivate_pd.drop('index', axis=1)
srl_motivate_pd
# Out:
#                                userid  intrinsic  extrinsic  task_value  \
# 0    b84f9624c8d995c6b945afc898bd9973       3.75       1.50    4.166667
# 1    481c56986ebae62c870b0da9bbafc5c6       4.50       4.50    4.500000
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698       5.00       4.50    5.000000
# 3    c054e8c731029ce6d73c784213513b09       4.25       5.00    4.000000
# 4    bebc49073c8a5def929612def946c281       3.25       3.50    3.833333
# ..                                ...        ...        ...         ...
# 378  1206c7660ccce9741cfc6fbea8764f1d       4.25       2.75    3.833333
# 379  d7f459f4c30a2dcfa42d2b0375f65ea3       3.75       4.25    4.666667
# 380  78061f2e805ef5e9707c636eecac64ef       4.00       2.75    4.500000
# 381  28f2c7a241f3d14b1dd47886efb6acee       3.75       5.00    4.000000
# 382  ff6a83db7cd1e89e7f401de25e5edcb7       3.00       3.25    3.000000
#
#      control_beliefs  self_efficacy  test_anxiety
# 0               3.50          3.375           1.6
# 1               4.50          4.500           4.6
# 2               5.00          4.750           3.2
# 3               4.50          4.125           4.4
# 4               4.00          4.000           1.0
# ..               ...            ...           ...
# 378             3.50          2.875           3.4
# 379             4.25          4.000           3.0
# 380             3.75          4.375           3.0
# 381             3.25          3.250           2.8
# 382             3.00          3.000           3.0
#
# [383 rows x 7 columns]

# %%
plt.figure(figsize=(10, 3))
srl_motivate_pd.boxplot()
plt.title('SRL Motivate Questionario')
plt.savefig('./data_plot/srl_motivation')
plt.show()

# %%
merged_pd = pd.merge(srl_motivate_pd, score_pd, on='userid', how='outer')

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f2a7c_row0_col0, #T_f2a7c_row1_col1, #T_f2a7c_row2_col2, #T_f2a7c_row3_col3, #T_f2a7c_row4_col4, #T_f2a7c_row5_col5, #T_f2a7c_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f2a7c_row0_col1, #T_f2a7c_row4_col5, #T_f2a7c_row5_col0, #T_f2a7c_row5_col2, #T_f2a7c_row5_col3, #T_f2a7c_row5_col4, #T_f2a7c_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f2a7c_row0_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_f2a7c_row0_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_f2a7c_row0_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_f2a7c_row0_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f2a7c_row0_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f2a7c_row1_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_f2a7c_row1_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f2a7c_row1_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_f2a7c_row1_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f2a7c_row1_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f2a7c_row1_col6, #T_f2a7c_row4_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f2a7c_row2_col0, #T_f2a7c_row2_col4 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_f2a7c_row2_col1, #T_f2a7c_row2_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f2a7c_row2_col3, #T_f2a7c_row4_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f2a7c_row2_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_f2a7c_row3_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_f2a7c_row3_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_f2a7c_row3_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_f2a7c_row3_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_f2a7c_row3_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f2a7c_row3_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_f2a7c_row4_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_f2a7c_row4_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_f2a7c_row4_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_f2a7c_row5_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_f2a7c_row6_col0, #T_f2a7c_row6_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_f2a7c_row6_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f2a7c_row6_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_f2a7c_row6_col4 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_f2a7c_row6_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2a7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2a7c_level0_col0" class="col_heading level0 col0" >intrinsic</th>
#       <th id="T_f2a7c_level0_col1" class="col_heading level0 col1" >extrinsic</th>
#       <th id="T_f2a7c_level0_col2" class="col_heading level0 col2" >task_value</th>
#       <th id="T_f2a7c_level0_col3" class="col_heading level0 col3" >control_beliefs</th>
#       <th id="T_f2a7c_level0_col4" class="col_heading level0 col4" >self_efficacy</th>
#       <th id="T_f2a7c_level0_col5" class="col_heading level0 col5" >test_anxiety</th>
#       <th id="T_f2a7c_level0_col6" class="col_heading level0 col6" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2a7c_level0_row0" class="row_heading level0 row0" >intrinsic</th>
#       <td id="T_f2a7c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f2a7c_row0_col1" class="data row0 col1" >0.162027</td>
#       <td id="T_f2a7c_row0_col2" class="data row0 col2" >0.602349</td>
#       <td id="T_f2a7c_row0_col3" class="data row0 col3" >0.519832</td>
#       <td id="T_f2a7c_row0_col4" class="data row0 col4" >0.565620</td>
#       <td id="T_f2a7c_row0_col5" class="data row0 col5" >-0.173297</td>
#       <td id="T_f2a7c_row0_col6" class="data row0 col6" >0.187803</td>
#     </tr>
#     <tr>
#       <th id="T_f2a7c_level0_row1" class="row_heading level0 row1" >extrinsic</th>
#       <td id="T_f2a7c_row1_col0" class="data row1 col0" >0.162027</td>
#       <td id="T_f2a7c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f2a7c_row1_col2" class="data row1 col2" >0.278029</td>
#       <td id="T_f2a7c_row1_col3" class="data row1 col3" >0.294422</td>
#       <td id="T_f2a7c_row1_col4" class="data row1 col4" >0.370888</td>
#       <td id="T_f2a7c_row1_col5" class="data row1 col5" >0.234372</td>
#       <td id="T_f2a7c_row1_col6" class="data row1 col6" >0.169035</td>
#     </tr>
#     <tr>
#       <th id="T_f2a7c_level0_row2" class="row_heading level0 row2" >task_value</th>
#       <td id="T_f2a7c_row2_col0" class="data row2 col0" >0.602349</td>
#       <td id="T_f2a7c_row2_col1" class="data row2 col1" >0.278029</td>
#       <td id="T_f2a7c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f2a7c_row2_col3" class="data row2 col3" >0.557730</td>
#       <td id="T_f2a7c_row2_col4" class="data row2 col4" >0.566623</td>
#       <td id="T_f2a7c_row2_col5" class="data row2 col5" >-0.098435</td>
#       <td id="T_f2a7c_row2_col6" class="data row2 col6" >0.238490</td>
#     </tr>
#     <tr>
#       <th id="T_f2a7c_level0_row3" class="row_heading level0 row3" >control_beliefs</th>
#       <td id="T_f2a7c_row3_col0" class="data row3 col0" >0.519832</td>
#       <td id="T_f2a7c_row3_col1" class="data row3 col1" >0.294422</td>
#       <td id="T_f2a7c_row3_col2" class="data row3 col2" >0.557730</td>
#       <td id="T_f2a7c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f2a7c_row3_col4" class="data row3 col4" >0.574237</td>
#       <td id="T_f2a7c_row3_col5" class="data row3 col5" >-0.114078</td>
#       <td id="T_f2a7c_row3_col6" class="data row3 col6" >0.217128</td>
#     </tr>
#     <tr>
#       <th id="T_f2a7c_level0_row4" class="row_heading level0 row4" >self_efficacy</th>
#       <td id="T_f2a7c_row4_col0" class="data row4 col0" >0.565620</td>
#       <td id="T_f2a7c_row4_col1" class="data row4 col1" >0.370888</td>
#       <td id="T_f2a7c_row4_col2" class="data row4 col2" >0.566623</td>
#       <td id="T_f2a7c_row4_col3" class="data row4 col3" >0.574237</td>
#       <td id="T_f2a7c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f2a7c_row4_col5" class="data row4 col5" >-0.277492</td>
#       <td id="T_f2a7c_row4_col6" class="data row4 col6" >0.321325</td>
#     </tr>
#     <tr>
#       <th id="T_f2a7c_level0_row5" class="row_heading level0 row5" >test_anxiety</th>
#       <td id="T_f2a7c_row5_col0" class="data row5 col0" >-0.173297</td>
#       <td id="T_f2a7c_row5_col1" class="data row5 col1" >0.234372</td>
#       <td id="T_f2a7c_row5_col2" class="data row5 col2" >-0.098435</td>
#       <td id="T_f2a7c_row5_col3" class="data row5 col3" >-0.114078</td>
#       <td id="T_f2a7c_row5_col4" class="data row5 col4" >-0.277492</td>
#       <td id="T_f2a7c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_f2a7c_row5_col6" class="data row5 col6" >-0.107056</td>
#     </tr>
#     <tr>
#       <th id="T_f2a7c_level0_row6" class="row_heading level0 row6" >score</th>
#       <td id="T_f2a7c_row6_col0" class="data row6 col0" >0.187803</td>
#       <td id="T_f2a7c_row6_col1" class="data row6 col1" >0.169035</td>
#       <td id="T_f2a7c_row6_col2" class="data row6 col2" >0.238490</td>
#       <td id="T_f2a7c_row6_col3" class="data row6 col3" >0.217128</td>
#       <td id="T_f2a7c_row6_col4" class="data row6 col4" >0.321325</td>
#       <td id="T_f2a7c_row6_col5" class="data row6 col5" >-0.107056</td>
#       <td id="T_f2a7c_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                  intrinsic  extrinsic  task_value  control_beliefs  \
# intrinsic         1.000000   0.162027    0.602349         0.519832
# extrinsic         0.162027   1.000000    0.278029         0.294422
# task_value        0.602349   0.278029    1.000000         0.557730
# control_beliefs   0.519832   0.294422    0.557730         1.000000
# self_efficacy     0.565620   0.370888    0.566623         0.574237
# test_anxiety     -0.173297   0.234372   -0.098435        -0.114078
# score             0.187803   0.169035    0.238490         0.217128
#
#                  self_efficacy  test_anxiety     score
# intrinsic             0.565620     -0.173297  0.187803
# extrinsic             0.370888      0.234372  0.169035
# task_value            0.566623     -0.098435  0.238490
# control_beliefs       0.574237     -0.114078  0.217128
# self_efficacy         1.000000     -0.277492  0.321325
# test_anxiety         -0.277492      1.000000 -0.107056
# score                 0.321325     -0.107056  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # SRL Strategy

# %%
srl_strategy_pd = pd.read_csv('./data/srl_strategy.csv')

# %%
# Calculate Standard Deviation & Delete the data which sd=0
question_list = srl_strategy_pd.columns[1:51]
srl_strategy_pd['sd'] = srl_strategy_pd[question_list].std(axis=1)
keep_list = srl_strategy_pd['sd'] > 0
srl_strategy_pd = srl_strategy_pd[keep_list]


'''
    Merge by Category 
    ---------------------------
    category      : Question number
    ---------------------------
    rehearsal         : 1-4    (4)
    elaboration       : 5-10   (6)
    organization      : 11-14  (4)
    critical_thinking : 15-19  (5)
    metacognitive_self_regulation   : 20-31 (12)
    time_environment  : 32-39  (8)
    effort_regulation : 40-43  (4)
    peer_learning     : 44-46  (3)
    help_seeking      : 47-50  (4)
'''

# classify data with same category
i = 1
rehearsal = srl_strategy_pd.columns[i:i+4]
i = i + 4
elaboration = srl_strategy_pd.columns[i:i+6]
i = i + 6
organization = srl_strategy_pd.columns[i:i+4]
i = i + 4
critical_thinking = srl_strategy_pd.columns[i:i+5]
i = i + 5
metacognitive_self_regulation = srl_strategy_pd.columns[i:i+12]
i = i + 12
time_environment = srl_strategy_pd.columns[i:i+8]
i = i + 8
effort_regulation = srl_strategy_pd.columns[i:i+4]
i = i + 4
peer_learning = srl_strategy_pd.columns[i:i+3]
i = i + 3
help_seeking = srl_strategy_pd.columns[i:i+4]


# avg
srl_strategy_pd['rehearsal'] = srl_strategy_pd[rehearsal].sum(axis=1) / 4
srl_strategy_pd['elaboration'] = srl_strategy_pd[elaboration].sum(axis=1) / 6
srl_strategy_pd['organization'] = srl_strategy_pd[organization].sum(axis=1) / 4
srl_strategy_pd['critical_thinking'] = srl_strategy_pd[critical_thinking].sum(axis=1)/ 5
srl_strategy_pd['metacognitive_self_regulation'] = srl_strategy_pd[metacognitive_self_regulation].sum(axis=1)/12
srl_strategy_pd['time_environment'] = srl_strategy_pd[time_environment].sum(axis=1)/8
srl_strategy_pd['effort_regulation'] = srl_strategy_pd[effort_regulation].sum(axis=1)/4
srl_strategy_pd['peer_learning'] = srl_strategy_pd[peer_learning].sum(axis=1)/3
srl_strategy_pd['help_seeking'] = srl_strategy_pd[help_seeking].sum(axis=1)/4

# keep data with same category
keep_list = ['userid', 'rehearsal', 'elaboration', 'organization', 'critical_thinking', 
             'metacognitive_self_regulation', 'time_environment', 'effort_regulation', 'peer_learning', 'help_seeking']
srl_strategy_pd = srl_strategy_pd[keep_list]
srl_strategy_pd = srl_strategy_pd.reset_index()
srl_strategy_pd = srl_strategy_pd.drop('index', axis=1)
srl_strategy_pd
# Out:
#                                userid  rehearsal  elaboration  organization  \
# 0    b64ce7758b9f7e58f1ad8bbcf7811e7d       4.75     4.666667          5.00
# 1    0cebfa477ed3e2e0c5a3f9aa96c23698       4.00     4.500000          4.50
# 2    0a715a568a054d7996fcbcbf17b36551       3.75     3.833333          3.75
# 3    ca7f48cb0d61ed7c967adf1a0010367e       4.75     3.166667          3.75
# 4    2979bd5d5a584c2aa70f4a434412bc2b       4.00     4.166667          4.00
# ..                                ...        ...          ...           ...
# 391  7ce2f134bef4e41403d1cff32f091816       4.25     4.333333          4.00
# 392  1c3a904d9038b01c612b2448fd1e58e0       4.00     4.000000          4.00
# 393  9d667d14467e79b6009a2012f50d4393       4.00     4.000000          4.50
# 394  1354bba0b3c3abbc330a6b971c896f3b       3.25     3.666667          3.00
# 395  70cac5f67dfcee0eb0313c42eeba9b90       4.00     3.833333          3.75
#
#      critical_thinking  metacognitive_self_regulation  time_environment  \
# 0                  3.2                       4.000000             3.375
# 1                  4.0                       4.000000             4.125
# 2                  3.8                       4.000000             3.375
# 3                  3.4                       3.500000             3.250
# 4                  3.8                       3.083333             4.000
# ..                 ...                            ...               ...
# 391                4.2                       3.916667             3.375
# 392                4.0                       4.000000             4.500
# 393                3.2                       3.666667             3.750
# 394                3.6                       3.416667             3.625
# 395                3.4                       3.500000             3.375
#
#      effort_regulation  peer_learning  help_seeking
# 0                 3.00       4.000000          4.75
# 1                 4.25       3.666667          4.00
# 2                 3.00       3.333333          3.25
# 3                 3.75       2.333333          3.25
# 4                 3.25       2.666667          3.50
# ..                 ...            ...           ...
# 391               3.25       4.333333          3.75
# 392               5.00       3.666667          3.50
# 393               3.25       4.333333          3.75
# 394               3.75       3.333333          3.50
# 395               4.00       2.333333          3.00
#
# [396 rows x 10 columns]

# %%
plt.figure(figsize=(10, 3))
srl_strategy_pd.boxplot()
plt.xticks(rotation=45)
plt.title('SRL Strategy Questionario')
results_path= './data_plot/srl_strategy'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
plt.show()

# %%
merged_pd = pd.merge(srl_strategy_pd, score_pd, on='userid', how='outer')

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f38ec_row0_col0, #T_f38ec_row1_col1, #T_f38ec_row2_col2, #T_f38ec_row3_col3, #T_f38ec_row4_col4, #T_f38ec_row5_col5, #T_f38ec_row6_col6, #T_f38ec_row7_col7, #T_f38ec_row8_col8, #T_f38ec_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f38ec_row0_col1, #T_f38ec_row0_col2, #T_f38ec_row2_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_f38ec_row0_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_f38ec_row0_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f38ec_row0_col5, #T_f38ec_row1_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f38ec_row0_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_f38ec_row0_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f38ec_row0_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f38ec_row0_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f38ec_row1_col0, #T_f38ec_row4_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_f38ec_row1_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f38ec_row1_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_f38ec_row1_col4, #T_f38ec_row3_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_f38ec_row1_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_f38ec_row1_col7, #T_f38ec_row3_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f38ec_row1_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f38ec_row1_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f38ec_row2_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f38ec_row2_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_f38ec_row2_col4, #T_f38ec_row3_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f38ec_row2_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f38ec_row2_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f38ec_row2_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f38ec_row2_col8, #T_f38ec_row3_col0, #T_f38ec_row8_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_f38ec_row2_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f38ec_row3_col2, #T_f38ec_row8_col0, #T_f38ec_row8_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f38ec_row3_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f38ec_row3_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_f38ec_row3_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f38ec_row3_col9, #T_f38ec_row7_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_f38ec_row4_col0 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f38ec_row4_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_f38ec_row4_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_f38ec_row4_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f38ec_row4_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f38ec_row4_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f38ec_row4_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_f38ec_row4_col9, #T_f38ec_row5_col9, #T_f38ec_row6_col0, #T_f38ec_row8_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_f38ec_row5_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f38ec_row5_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_f38ec_row5_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f38ec_row5_col3, #T_f38ec_row6_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f38ec_row5_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_f38ec_row5_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_f38ec_row5_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_f38ec_row5_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_f38ec_row6_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f38ec_row6_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_f38ec_row6_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f38ec_row6_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f38ec_row6_col7, #T_f38ec_row6_col8, #T_f38ec_row7_col1, #T_f38ec_row7_col5, #T_f38ec_row7_col6, #T_f38ec_row7_col9, #T_f38ec_row9_col0, #T_f38ec_row9_col1, #T_f38ec_row9_col2, #T_f38ec_row9_col3, #T_f38ec_row9_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f38ec_row6_col9, #T_f38ec_row7_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f38ec_row7_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f38ec_row7_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f38ec_row7_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f38ec_row8_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_f38ec_row8_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_f38ec_row8_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f38ec_row8_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_f38ec_row8_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f38ec_row9_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f38ec_row9_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f38ec_row9_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f38ec_row9_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f38ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f38ec_level0_col0" class="col_heading level0 col0" >rehearsal</th>
#       <th id="T_f38ec_level0_col1" class="col_heading level0 col1" >elaboration</th>
#       <th id="T_f38ec_level0_col2" class="col_heading level0 col2" >organization</th>
#       <th id="T_f38ec_level0_col3" class="col_heading level0 col3" >critical_thinking</th>
#       <th id="T_f38ec_level0_col4" class="col_heading level0 col4" >metacognitive_self_regulation</th>
#       <th id="T_f38ec_level0_col5" class="col_heading level0 col5" >time_environment</th>
#       <th id="T_f38ec_level0_col6" class="col_heading level0 col6" >effort_regulation</th>
#       <th id="T_f38ec_level0_col7" class="col_heading level0 col7" >peer_learning</th>
#       <th id="T_f38ec_level0_col8" class="col_heading level0 col8" >help_seeking</th>
#       <th id="T_f38ec_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f38ec_level0_row0" class="row_heading level0 row0" >rehearsal</th>
#       <td id="T_f38ec_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f38ec_row0_col1" class="data row0 col1" >0.597352</td>
#       <td id="T_f38ec_row0_col2" class="data row0 col2" >0.584968</td>
#       <td id="T_f38ec_row0_col3" class="data row0 col3" >0.341858</td>
#       <td id="T_f38ec_row0_col4" class="data row0 col4" >0.527623</td>
#       <td id="T_f38ec_row0_col5" class="data row0 col5" >0.392591</td>
#       <td id="T_f38ec_row0_col6" class="data row0 col6" >0.215001</td>
#       <td id="T_f38ec_row0_col7" class="data row0 col7" >0.109565</td>
#       <td id="T_f38ec_row0_col8" class="data row0 col8" >0.314481</td>
#       <td id="T_f38ec_row0_col9" class="data row0 col9" >0.067465</td>
#     </tr>
#     <tr>
#       <th id="T_f38ec_level0_row1" class="row_heading level0 row1" >elaboration</th>
#       <td id="T_f38ec_row1_col0" class="data row1 col0" >0.597352</td>
#       <td id="T_f38ec_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f38ec_row1_col2" class="data row1 col2" >0.527835</td>
#       <td id="T_f38ec_row1_col3" class="data row1 col3" >0.590022</td>
#       <td id="T_f38ec_row1_col4" class="data row1 col4" >0.603584</td>
#       <td id="T_f38ec_row1_col5" class="data row1 col5" >0.390705</td>
#       <td id="T_f38ec_row1_col6" class="data row1 col6" >0.230604</td>
#       <td id="T_f38ec_row1_col7" class="data row1 col7" >0.090439</td>
#       <td id="T_f38ec_row1_col8" class="data row1 col8" >0.310546</td>
#       <td id="T_f38ec_row1_col9" class="data row1 col9" >0.093436</td>
#     </tr>
#     <tr>
#       <th id="T_f38ec_level0_row2" class="row_heading level0 row2" >organization</th>
#       <td id="T_f38ec_row2_col0" class="data row2

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                                rehearsal  elaboration  organization  \
# rehearsal                       1.000000     0.597352      0.584968
# elaboration                     0.597352     1.000000      0.527835
# organization                    0.584968     0.527835      1.000000
# critical_thinking               0.341858     0.590022      0.309836
# metacognitive_self_regulation   0.527623     0.603584      0.497362
# time_environment                0.392591     0.390705      0.380213
# effort_regulation               0.215001     0.230604      0.260884
# peer_learning                   0.109565     0.090439      0.190481
# help_seeking                    0.314481     0.310546      0.357100
# score                           0.067465     0.093436      0.060681
#
#                                critical_thinking  \
# rehearsal                               0.341858
# elaboration                             0.590022
# organization                            0.309836
# critical_thinking                       1.000000
# metacognitive_self_regulation           0.497515
# time_environment                        0.248867
# effort_regulation                       0.099285
# peer_learning                           0.124255
# help_seeking                            0.235199
# score                                   0.044768
#
#                                metacognitive_self_regulation  \
# rehearsal                                           0.527623
# elaboration                                         0.603584
# organization                                        0.497362
# critical_thinking                                   0.497515
# metacognitive_self_regulation                       1.000000
# time_environment                                    0.578083
# effort_regulation                                   0.435512
# peer_learning                                       0.130338
# help_seeking                                        0.381008
# score                                               0.120396
#
#                                time_environment  effort_regulation  \
# rehearsal                              0.392591           0.215001
# elaboration                            0.390705           0.230604
# organization                           0.380213           0.260884
# critical_thinking                      0.248867           0.099285
# metacognitive_self_regulation          0.578083           0.435512
# time_environment                       1.000000           0.611655
# effort_regulation                      0.611655           1.000000
# peer_learning                          0.018230          -0.083106
# help_seeking                           0.245239           0.088246
# score                                  0.119546           0.002053
#
#                                peer_learning  help_seeking     score
# rehearsal                           0.109565      0.314481  0.067465
# elaboration                         0.090439      0.310546  0.093436
# organization                        0.190481      0.357100  0.060681
# critical_thinking                   0.124255      0.235199  0.044768
# metacognitive_self_regulation       0.130338      0.381008  0.120396
# time_environment                    0.018230      0.245239  0.119546
# effort_regulation                  -0.083106      0.088246  0.002053
# peer_learning                       1.000000      0.204444 -0.043857
# help_seeking                        0.204444      1.000000  0.113350
# score                              -0.043857      0.113350  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # Questionario & Score (correlation)

# %%
merged_pd = pd.merge( srl_motivate_pd, srl_strategy_pd, on='userid', how='outer')
merged_pd = pd.merge( merged_pd, sill_pd, on='userid', how='outer')
merged_pd = pd.merge( merged_pd, score_pd, on='userid', how='outer')
merged_pd
# Out:
#                                userid  intrinsic  extrinsic  task_value  \
# 0    b84f9624c8d995c6b945afc898bd9973       3.75        1.5    4.166667
# 1    481c56986ebae62c870b0da9bbafc5c6       4.50        4.5    4.500000
# 2    0cebfa477ed3e2e0c5a3f9aa96c23698       5.00        4.5    5.000000
# 3    c054e8c731029ce6d73c784213513b09       4.25        5.0    4.000000
# 4    bebc49073c8a5def929612def946c281       3.25        3.5    3.833333
# ..                                ...        ...        ...         ...
# 600  ba4bbe7a9c22e08fa8931bc566f28db1        NaN        NaN         NaN
# 601  b823e75b120a762d110d305a2f29145e        NaN        NaN         NaN
# 602  3c294e52e1779928413bc312cfd713b6        NaN        NaN         NaN
# 603  a79bcc5d4541fde75701045f55ef170c        NaN        NaN         NaN
# 604  50b8b51ed864f6b0b7eb5d173b6f2d25        NaN        NaN         NaN
#
#      control_beliefs  self_efficacy  test_anxiety  rehearsal  elaboration  \
# 0                3.5          3.375           1.6       4.00     4.000000
# 1                4.5          4.500           4.6       3.00     3.500000
# 2                5.0          4.750           3.2       4.00     4.500000
# 3                4.5          4.125           4.4       5.00     4.333333
# 4                4.0          4.000           1.0       4.25     3.833333
# ..               ...            ...           ...        ...          ...
# 600              NaN            NaN           NaN        NaN          NaN
# 601              NaN            NaN           NaN        NaN          NaN
# 602              NaN            NaN           NaN        NaN          NaN
# 603              NaN            NaN           NaN        NaN          NaN
# 604              NaN            NaN           NaN        NaN          NaN
#
#      organization  ...  peer_learning  help_seeking  memory  cognitive  \
# 0             3.0  ...       5.000000           4.5   3.500   3.923077
# 1             3.5  ...       4.000000           4.0   3.625   3.615385
# 2             4.5  ...       3.666667           4.0   4.875   4.846154
# 3             5.0  ...       1.000000           5.0   2.125   1.923077
# 4             4.0  ...       3.000000           3.5   3.375   3.615385
# ..            ...  ...            ...           ...     ...        ...
# 600           NaN  ...            NaN           NaN     NaN        NaN
# 601           NaN  ...            NaN           NaN     NaN        NaN
# 602           NaN  ...            NaN           NaN     NaN        NaN
# 603           NaN  ...            NaN           NaN     NaN        NaN
# 604           NaN  ...            NaN           NaN     NaN        NaN
#
#      compensation  metacognitive  affective    social  score  class
# 0        3.833333       3.555556   3.833333  3.500000   81.0      b
# 1        4.166667       3.555556   3.166667  3.000000   84.0      b
# 2        4.500000       4.888889   4.500000  4.333333   98.0      b
# 3        1.833333       2.666667   3.000000  1.333333   90.0      b
# 4        4.333333       3.777778   3.500000  3.666667   85.0      b
# ..            ...            ...        ...       ...    ...    ...
# 600           NaN            NaN        NaN       NaN   92.0      l
# 601           NaN            NaN        NaN       NaN    0.0      l
# 602           NaN            NaN        NaN       NaN   66.0      l
# 603           NaN            NaN        NaN       NaN   68.0      l
# 604           NaN            NaN        NaN       NaN   87.0      l
#
# [605 rows x 24 columns]

# %%
plt.figure(figsize=(15, 5))
merged_pd.drop('score', axis=1).boxplot()
plt.title('Questionario')
plt.xticks(rotation='vertical')
plt.savefig('./data_plot/all_questionario', dpi='figure', bbox_inches='tight')
plt.show()

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7024f_row0_col0, #T_7024f_row1_col1, #T_7024f_row2_col2, #T_7024f_row3_col3, #T_7024f_row4_col4, #T_7024f_row5_col5, #T_7024f_row6_col6, #T_7024f_row7_col7, #T_7024f_row8_col8, #T_7024f_row9_col9, #T_7024f_row10_col10, #T_7024f_row11_col11, #T_7024f_row12_col12, #T_7024f_row13_col13, #T_7024f_row14_col14, #T_7024f_row15_col15, #T_7024f_row16_col16, #T_7024f_row17_col17, #T_7024f_row18_col18, #T_7024f_row19_col19, #T_7024f_row20_col20, #T_7024f_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col1, #T_7024f_row1_col16, #T_7024f_row13_col20, #T_7024f_row21_col12 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_7024f_row0_col3, #T_7024f_row2_col7, #T_7024f_row7_col2, #T_7024f_row17_col15 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_7024f_row0_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_7024f_row0_col5, #T_7024f_row16_col8, #T_7024f_row21_col17 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col6, #T_7024f_row4_col21, #T_7024f_row14_col19 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_7024f_row0_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_7024f_row0_col8, #T_7024f_row11_col18, #T_7024f_row16_col12, #T_7024f_row21_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col9 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_7024f_row0_col10, #T_7024f_row1_col7, #T_7024f_row7_col12, #T_7024f_row14_col2, #T_7024f_row18_col9 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_7024f_row0_col11, #T_7024f_row11_col3, #T_7024f_row19_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_7024f_row0_col12, #T_7024f_row0_col18, #T_7024f_row10_col17 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_7024f_row0_col13, #T_7024f_row6_col5, #T_7024f_row9_col14, #T_7024f_row12_col9, #T_7024f_row17_col10 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col14, #T_7024f_row5_col18, #T_7024f_row5_col20, #T_7024f_row7_col5, #T_7024f_row15_col10, #T_7024f_row21_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col15, #T_7024f_row1_col14, #T_7024f_row11_col20, #T_7024f_row15_col14, #T_7024f_row17_col12, #T_7024f_row18_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col16, #T_7024f_row1_col19, #T_7024f_row3_col14, #T_7024f_row3_col19, #T_7024f_row6_col15, #T_7024f_row9_col8, #T_7024f_row13_col18, #T_7024f_row14_col13 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_7024f_row0_col17, #T_7024f_row7_col1, #T_7024f_row7_col15, #T_7024f_row7_col18 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7024f_row0_col19, #T_7024f_row1_col0, #T_7024f_row1_col12, #T_7024f_row4_col19 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_7024f_row0_col20 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_7024f_row0_col21, #T_7024f_row3_col18, #T_7024f_row4_col11, #T_7024f_row12_col0, #T_7024f_row16_col2, #T_7024f_row18_col2, #T_7024f_row18_col7, #T_7024f_row19_col0, #T_7024f_row19_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_7024f_row1_col2, #T_7024f_row6_col19, #T_7024f_row7_col16, #T_7024f_row11_col8 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_7024f_row1_col3, #T_7024f_row9_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_7024f_row1_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7024f_row1_col5, #T_7024f_row2_col9, #T_7024f_row8_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_7024f_row1_col6, #T_7024f_row2_col1, #T_7024f_row6_col16, #T_7024f_row6_col18, #T_7024f_row8_col5, #T_7024f_row14_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_7024f_row1_col8, #T_7024f_row2_col12, #T_7024f_row2_col17, #T_7024f_row7_col19, #T_7024f_row12_col7, #T_7024f_row14_col0, #T_7024f_row14_col17 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_7024f_row1_col9, #T_7024f_row6_col14, #T_7024f_row13_col19 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7024f_row1_col10, #T_7024f_row3_col6, #T_7024f_row7_col17 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7024f_row1_col11, #T_7024f_row4_col13, #T_7024f_row8_col16, #T_7024f_row11_col1, #T_7024f_row13_col15, #T_7024f_row14_col21, #T_7024f_row20_col12, #T_7024f_row20_col14 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_7024f_row1_col13, #T_7024f_row15_col5, #T_7024f_row17_col11, #T_7024f_row19_col14 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_7024f_row1_col15, #T_7024f_row2_col5, #T_7024f_row13_col8, #T_7024f_row15_col12, #T_7024f_row16_col13, #T_7024f_row18_col1, #T_7024f_row18_col10, #T_7024f_row20_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_7024f_row1_col17, #T_7024f_row15_col11, #T_7024f_row16_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_7024f_row1_col18, #T_7024f_row2_col20, #T_7024f_row12_col2, #T_7024f_row19_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_7024f_row1_col20, #T_7024f_row4_col20, #T_7024f_row5_col1, #T_7024f_row8_col20, #T_7024f_row14_col12, #T_7024f_row15_col6, #T_7024f_row18_col14, #T_7024f_row19_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_7024f_row1_col21, #T_7024f_row2_col14, #T_7024f_row3_col12, #T_7024f_row4_col12, #T_7024f_row8_col13, #T_7024f_row13_col0, #T_7024f_row14_col11, #T_7024f_row16_col6, #T_7024f_row20_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_7024f_row2_col0, #T_7024f_row2_col4 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_7024f_row2_col3, #T_7024f_row4_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_7024f_row2_col6, #T_7024f_row6_col11, #T_7024f_row7_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_7024f_row2_col8, #T_7024f_row2_col18, #T_7024f_row3_col1, #T_7024f_row3_col21, #T_7024f_row12_col4, #T_7024f_row14_col16, #T_7024f_row15_col0, #T_7024f_row15_col4, #T_7024f_row21_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_7024f_row2_col10, #T_7024f_row11_col6, #T_7024f_row17_col9 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_7024f_row2_col11, #T_7024f_row15_col9, #T_7024f_row16_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_7024f_row2_col13, #T_7024f_row8_col15, #T_7024f_row18_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_7024f_row2_col15, #T_7024f_row3_col16, #T_7024f_row5_col19, #T_7024f_row10_col5, #T_7024f_row11_col19 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7024f_row2_col16, #T_7024f_row3_col11, #T_7024f_row6_col1, #T_7024f_row7_col20, #T_7024f_row14_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_7024f_row2_col19 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_7024f_row2_col21, #T_7024f_row10_col20, #T_7024f_row14_col8, #T_7024f_row14_col9, #T_7024f_row15_col7, #T_7024f_row18_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_7024f_row3_col0, #T_7024f_row9_col4, #T_7024f_row15_col17 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_7024f_row3_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_7024f_row3_col4, #T_7024f_row17_col18, #T_7024f_row18_col17 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_7024f_row3_col5, #T_7024f_row9_col5, #T_7024f_row19_col10, #T_7024f_row21_col11 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_7024f_row3_col7, #T_7024f_row17_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_7024f_row3_col8, #T_7024f_row3_col13, #T_7024f_row6_col17, #T_7024f_row11_col16, #T_7024f_row13_col2, #T_7024f_row13_col5, #T_7024f_row18_col13, #T_7024f_row20_col2, #T_7024f_row20_col10 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7024f_row3_col9, #T_7024f_row8_col1, #T_7024f_row8_col3, #T_7024f_row8_col4, #T_7024f_row9_col3, #T_7024f_row9_col20, #T_7024f_row20_col9 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7024f_row3_col10, #T_7024f_row8_col0, #T_7024f_row14_col6, #T_7024f_row20_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_7024f_row3_col15, #T_7024f_row13_col10 {
#   background-color: #6180e9

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
corr
# Out:
#                                intrinsic  extrinsic  task_value  \
# intrinsic                       1.000000   0.162027    0.602349
# extrinsic                       0.162027   1.000000    0.278029
# task_value                      0.602349   0.278029    1.000000
# control_beliefs                 0.519832   0.294422    0.557730
# self_efficacy                   0.565620   0.370888    0.566623
# test_anxiety                   -0.173297   0.234372   -0.098435
# rehearsal                       0.366570   0.256055    0.376166
# elaboration                     0.436089   0.291531    0.525171
# organization                    0.225071   0.346665    0.341658
# critical_thinking               0.381761   0.191115    0.330675
# metacognitive_self_regulation   0.364880   0.339395    0.422844
# time_environment                0.327446   0.199244    0.349622
# effort_regulation               0.146596   0.144641    0.161234
# peer_learning                   0.121532   0.154192    0.152001
# help_seeking                    0.183645   0.276237    0.292984
# memory                          0.178922   0.078186    0.170880
# cognitive                       0.203186   0.100385    0.198680
# compensation                    0.202098  -0.007547    0.209996
# metacognitive                   0.193380   0.132954    0.201662
# affective                       0.143337   0.114244    0.172082
# social                          0.056255   0.155111    0.151105
# score                           0.187803   0.169035    0.238490
#
#                                control_beliefs  self_efficacy  test_anxiety  \
# intrinsic                             0.519832       0.565620     -0.173297
# extrinsic                             0.294422       0.370888      0.234372
# task_value                            0.557730       0.566623     -0.098435
# control_beliefs                       1.000000       0.574237     -0.114078
# self_efficacy                         0.574237       1.000000     -0.277492
# test_anxiety                         -0.114078      -0.277492      1.000000
# rehearsal                             0.308443       0.251245     -0.036966
# elaboration                           0.394257       0.490793     -0.104341
# organization                          0.277126       0.169178      0.084283
# critical_thinking                     0.275231       0.476713     -0.113609
# metacognitive_self_regulation         0.342962       0.384778      0.008908
# time_environment                      0.255101       0.268362     -0.006845
# effort_regulation                     0.102883       0.102264      0.033942
# peer_learning                         0.163132       0.138268      0.016306
# help_seeking                          0.306758       0.199209      0.056468
# memory                                0.062442       0.104455      0.006449
# cognitive                             0.158872       0.262210     -0.084629
# compensation                          0.094650       0.298363     -0.130848
# metacognitive                         0.170433       0.213835      0.018024
# affective                             0.117353       0.142173      0.070614
# social                                0.048228       0.153123      0.037174
# score                                 0.217128       0.321325     -0.107056
#
#                                rehearsal  elaboration  organization  \
# intrinsic                       0.366570     0.436089      0.225071
# extrinsic                       0.256055     0.291531      0.346665
# task_value                      0.376166     0.525171      0.341658
# control_beliefs                 0.308443     0.394257      0.277126
# self_efficacy                   0.251245     0.490793      0.169178
# test_anxiety                   -0.036966    -0.104341      0.084283
# rehearsal                       1.000000     0.597352      0.584968
# elaboration                     0.597352     1.000000      0.527835
# organization                    0.584968     0.527835      1.000000
# critical_thinking               0.341858     0.590022      0.309836
# metacognitive_self_regulation   0.527623     0.603584      0.497362
# time_environment                0.392591     0.390705      0.380213
# effort_regulation               0.215001     0.230604      0.260884
# peer_learning                   0.109565     0.090439      0.190481
# help_seeking                    0.314481     0.310546      0.357100
# memory                          0.212461     0.244055      0.163662
# cognitive                       0.223751     0.286718      0.136527
# compensation                    0.126940     0.248114      0.092327
# metacognitive                   0.187057     0.196741      0.153701
# affective                       0.209749     0.162209      0.119588
# social                          0.108307     0.173686      0.153939
# score                           0.067465     0.093436      0.060681
#
#                                critical_thinking  ...  effort_regulation  \
# intrinsic                               0.381761  ...           0.146596
# extrinsic                               0.191115  ...           0.144641
# task_value                              0.330675  ...           0.161234
# control_beliefs                         0.275231  ...           0.102883
# self_efficacy                           0.476713  ...           0.102264
# test_anxiety                           -0.113609  ...           0.033942
# rehearsal                               0.341858  ...           0.215001
# elaboration                             0.590022  ...           0.230604
# organization                            0.309836  ...           0.260884
# critical_thinking                       1.000000  ...           0.099285
# metacognitive_self_regulation           0.497515  ...           0.435512
# time_environment                        0.248867  ...           0.611655
# effort_regulation                       0.099285  ...           1.000000
# peer_learning                           0.124255  ...          -0.083106
# help_seeking                            0.235199  ...           0.088246
# memory                                  0.279909  ...          -0.033836
# cognitive                               0.374738  ...           0.006218
# compensation                            0.349084  ...           0.076304
# metacognitive                           0.283266  ...          -0.136481
# affective                               0.251001  ...          -0.200677
# social                                  0.276283  ...           0.047094
# score                                   0.044768  ...           0.002053
#
#                                peer_learning  help_seeking    memory  \
# intrinsic                           0.121532      0.183645  0.178922
# extrinsic                           0.154192      0.276237  0.078186
# task_value                          0.152001      0.292984  0.170880
# control_beliefs                     0.163132      0.306758  0.062442
# self_efficacy                       0.138268      0.199209  0.104455
# test_anxiety                        0.016306      0.056468  0.006449
# rehearsal                           0.109565      0.314481  0.212461
# elaboration                         0.090439      0.310546  0.244055
# organization                        0.190481      0.357100  0.163662
# critical_thinking                   0.124255      0.235199  0.279909
# metacognitive_self_regulation       0.130338      0.381008  0.143646
# time_environment                    0.018230      0.245239  0.099874
# effort_regulation                  -0.083106      0.088246 -0.033836
# peer_learning                       1.000000      0.204444  0.148036
# help_seeking                        0.204444      1.000000  0.275570
# memory                              0.148036      0.275570  1.000000
# cognitive                           0.069061      0.237436  0.706743
# compensation                        0.035816      0.213340  0.538615
# metacognitive                       0.164759      0.283822  0.646550
# affective                           0.127956      0.265409  0.586025
# social                              0.074029      0.251050  0.499806
# score                              -0.043857      0.113350 -0.069890
#
#                                cognitive  compensation  metacognitive  \
# intrinsic                       0.203186      0.202098       0.193380
# extrinsic                       0.100385     -0.007547       0.132954
# task_value                      0.198680      0.209996       0.201662
# control_beliefs                 0.158872      0.094650       0.170433
# self_efficacy                   0.262210      0.298363       0.213835
# test_anxiety                   -0.084629     -0.130848       0.018024
# rehearsal                       0.223751      0.126940       0.187057
# elaboration                     0.286718      0.248114       0.196741
# organization                    0.136527      0.092327       0.153701
# critical_thinking               0.374738      0.349084       0.283266
# metacognitive_self_regulation   0.219386      0.197088       0.144662
# time_environment                0.162039      0.214793       0.062439
# effort_regulation               0.006218      0.076304      -0.136481
# peer_learning                   0.069061      0.035816       0.164759
# help_seeking                    0.237436      0.213340       0.283822
# memory                          0.706743      0.538615       0.646550
# cognitive                       1.000000      0.732330       0.757638
# compensation                    0.732330      1.000000       0.620841
# metacognitive                   0.757638      0.620841       1.000000
# affective                       0.554484      0.462787       0.742403
# social                          0.676076      0.639597       0.646597
# score                          -0.062287     -0.039462      -0.107385
#
#                                affective    social     score
# intrinsic                       0.143337  0.056255  0.187803
# extrinsic                       0.114244  0.155111  0.169035
# task_value                      0.172082  0.151105  0.238490
# control_beliefs                 0.117353  0.048228  0.217128
# self_efficacy                   0.142173  0.153123  0.321325
# test_anxiety                    0.070614  0.037174 -0.107056
# rehearsal                       0.209749  0.108307  0.067465
# elaboration                     0.162209  0.173686  0.093436
# organization                    0.119588  0.153939  0.060681
# critical_thinking               0.251001  0.276283  0.044768
# metacognitive_self_regulation   0.133313  0.234760  0.120396
# time_environment                0.066927  0.144659  0.119546
# effort_regulation              -0.200677  0.047094  0.002053
# peer_learning                   0.127956  0.074029 -0.043857
# help_seeking                    0.265409  0.251050  0.113350
# memory                          0.586025  0.499806 -0.069890
# cognitive                       0.554484  0.676076 -0.062287
# compensation                    0.462787  0.639597 -0.039462
# metacognitive                   0.742403  0.646597 -0.107385
# affective                       1.000000  0.500805 -0.107494
# social                          0.500805  1.000000 -0.113500
# score                          -0.107494 -0.113500  1.000000
#
# [22 rows x 22 columns]

# %%
ax = plt.axes()
ax.set_title('Questionario Correlation')

sns_plot = sns.heatmap(corr)

results_path = './data_plot/Questionario_Correlation.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')

# %% [markdown]
# ## viscode

# %%
viscode_pd = pd.read_csv('./data/viscode.csv')
#viscode_pd = viscode_pd.drop(['Unnamed: 0', 'userid', 'score', 'class' ], axis=1)

# %%
viscode_pd.nunique()
# Out:
# userid                     546
# code_copy                  377
# code_execution             452
# code_paste                 417
# code_speed                 516
# notebook_open              290
# tree_open                  118
# use_copilot                  2
# AssertionError               2
# AttributeError              42
# AxisError                    2
# ConversionError              3
# DataError                    2
# EmptyDataError               7
# Exception                    3
# FeatureNotFound              2
# FileExistsError              2
# FileNotFoundError           13
# HTTPError                    3
# ImportError                  4
# IndentationError            66
# IndexError                  30
# IndexingError                2
# InvalidURL                   2
# KeyError                    41
# KeyboardInterrupt           25
# ModuleNotFoundError         11
# NameError                   76
# OSError                      2
# OverflowError                2
# ParserError                 11
# RecursionError              10
# RuntimeError                 6
# SelectorSyntaxError          2
# SpecificationError           2
# StopIteration                3
# SyntaxError                184
# TabError                    16
# TclError                     2
# TypeError                   65
# UFuncTypeError               2
# UnboundLocalError           13
# UndefinedVariableError       2
# ValueError                  34
# WebDriverException           2
# XLRDError                    2
# ZeroDivisionError           11
# codeLength                 518
# Viscode-login_times        319
# Viscode-execute_times      501
# Viscode-open_file_times    290
# Viscode-success_run        503
# Viscode-failed_run         268
# Viscode-error_types         17
# Viscode-spent_time         540
# dtype: int64

# %%
plt.figure(figsize=(20, 3))



plt.subplot(1, 3, 1)
viscode_pd[['code_copy', 'code_execution', 'code_paste', 'notebook_open', 'tree_open']].boxplot()

plt.xticks(rotation=90)


plt.subplot(1, 3, 2)
viscode_pd[['Viscode-login_times', 'Viscode-execute_times', 'Viscode-open_file_times', 'Viscode-success_run', 'Viscode-failed_run', 'Viscode-error_types', 'Viscode-spent_time']].boxplot()
plt.xticks(rotation=90)

plt.title('VisCode Features Distribution')

# plt.subplot(1, 3, 3)
# viscode_pd[['code_speed', 'codeLength' ]].boxplot()
# plt.xticks(rotation=90)

plt.subplot(1, 3, 3)
viscode_pd.drop(['codeLength','code_copy', 'code_execution', 'code_paste', 'code_speed', 'notebook_open', 'tree_open', 'Viscode-login_times', 'Viscode-execute_times', 'Viscode-open_file_times', 'Viscode-success_run', 'Viscode-failed_run', 'Viscode-error_types', 'Viscode-spent_time'], axis=1).boxplot() # 
plt.xticks(rotation=90)




results_path = './data_plot/VisCode_Features_Distribution.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15, 5))
viscode_pd[['IndentationError', 'NameError', 'SyntaxError', 'TypeError', 'AttributeError', 'KeyError']].boxplot()
# Out:
# <Axes: >

# %%
viscode_pd = pd.read_csv('./data/viscode.csv')
#viscode_pd = viscode_pd.drop(['Unnamed: 0', 'class', 'score'], axis =1)
viscode_pd
# Out:
#                                userid  code_copy  code_execution  code_paste  \
# 0    01291c313aef72b9786046bd7ce4cfca        584            1398         714
# 1    019acd030e0cdf674dda03e2a8ca4369        507             887         670
# 2    01ea38c4c3cc5fba869732fc641ca884        176             582         264
# 3    023c88ec58c8cf0abcfbcea4166793ad         89             588         137
# 4    02d679ad650962b6ae8bf8adbeeb33c1         69             545         150
# ..                                ...        ...             ...         ...
# 541  fde0bceed4e87f770bbb3e07bec22d05       1102            1275        1421
# 542  fe893f4359d6a6a550d109199d5f10f4        106            1044         129
# 543  ff352cc412dda02baf83e6c095f81622        394            1270         520
# 544  ff6a83db7cd1e89e7f401de25e5edcb7         10               9          20
# 545  ffc7749aa8337fadddcbd42d9cf6e5ec        284             820         358
#
#      code_speed  notebook_open  tree_open  use_copilot  AssertionError  \
# 0          5181            439         70            0             0.0
# 1          4827            254         70            0             0.0
# 2          1521             73         35            0             0.0
# 3          1563             79         44            0             0.0
# 4          1119             41         24            0             0.0
# ..          ...            ...        ...          ...             ...
# 541        5092            308         83            0             0.0
# 542        2840            125         50            0             0.0
# 543        4938            329        118            0             0.0
# 544          54              4          2            0             0.0
# 545        3362            191         33            0             0.0
#
#      AttributeError  ...  XLRDError  ZeroDivisionError  codeLength  \
# 0               8.0  ...        0.0                0.0      4710.0
# 1               8.0  ...        0.0                0.0      1368.0
# 2               7.0  ...        0.0                0.0      3543.0
# 3               8.0  ...        0.0                0.0      3472.0
# 4               2.0  ...        0.0                0.0      1228.0
# ..              ...  ...        ...                ...         ...
# 541             7.0  ...        0.0                0.0      5206.0
# 542            29.0  ...        0.0                0.0      3714.0
# 543             2.0  ...        0.0                0.0      3934.0
# 544             0.0  ...        0.0                0.0       194.0
# 545             5.0  ...        0.0                0.0       982.0
#
#      Viscode-login_times  Viscode-execute_times  Viscode-open_file_times  \
# 0                    509                   3205                    439.0
# 1                    324                   2388                    254.0
# 2                    108                   1130                     73.0
# 3                    123                    937                     79.0
# 4                     65                    829                     41.0
# ..                   ...                    ...                      ...
# 541                  391                   4189                    308.0
# 542                  175                   1454                    125.0
# 543                  447                   2631                    329.0
# 544                    6                     45                      4.0
# 545                  224                   1686                    191.0
#
#      Viscode-success_run  Viscode-failed_run  Viscode-error_types  \
# 0                   2950               255.0                 10.0
# 1                   2256               132.0                  7.0
# 2                   1020               110.0                  8.0
# 3                    811               126.0                  6.0
# 4                    701               128.0                  7.0
# ..                   ...                 ...                  ...
# 541                 4048               141.0                  9.0
# 542                 1090               364.0                 11.0
# 543                 2399               232.0                  9.0
# 544                   43                 2.0                  1.0
# 545                 1573               113.0                  7.0
#
#          Viscode-spent_time
# 0    0 days 02:28:28.302167
# 1    0 days 01:24:59.160120
# 2    0 days 00:50:32.025803
# 3    0 days 00:54:26.187369
# 4    0 days 01:06:30.302228
# ..                      ...
# 541  0 days 02:13:10.995293
# 542  0 days 01:39:59.864313
# 543  0 days 02:07:27.617555
# 544  0 days 00:00:25.883548
# 545  0 days 01:29:48.690987
#
# [546 rows x 55 columns]

# %%
merge_pd = pd.merge(viscode_pd, score_pd, on='userid', how = 'outer')
merge_pd = merge_pd.drop( 'userid', axis =1)
merge_pd
# Out:
#      code_copy  code_execution  code_paste  code_speed  notebook_open  \
# 0        584.0          1398.0       714.0      5181.0          439.0
# 1        507.0           887.0       670.0      4827.0          254.0
# 2        176.0           582.0       264.0      1521.0           73.0
# 3         89.0           588.0       137.0      1563.0           79.0
# 4         69.0           545.0       150.0      1119.0           41.0
# ..         ...             ...         ...         ...            ...
# 593        NaN             NaN         NaN         NaN            NaN
# 594        NaN             NaN         NaN         NaN            NaN
# 595        NaN             NaN         NaN         NaN            NaN
# 596        NaN             NaN         NaN         NaN            NaN
# 597        NaN             NaN         NaN         NaN            NaN
#
#      tree_open  use_copilot  AssertionError  AttributeError  AxisError  ...  \
# 0         70.0          0.0             0.0             8.0        0.0  ...
# 1         70.0          0.0             0.0             8.0        0.0  ...
# 2         35.0          0.0             0.0             7.0        0.0  ...
# 3         44.0          0.0             0.0             8.0        0.0  ...
# 4         24.0          0.0             0.0             2.0        0.0  ...
# ..         ...          ...             ...             ...        ...  ...
# 593        NaN          NaN             NaN             NaN        NaN  ...
# 594        NaN          NaN             NaN             NaN        NaN  ...
# 595        NaN          NaN             NaN             NaN        NaN  ...
# 596        NaN          NaN             NaN             NaN        NaN  ...
# 597        NaN          NaN             NaN             NaN        NaN  ...
#
#      codeLength  Viscode-login_times  Viscode-execute_times  \
# 0        4710.0                509.0                 3205.0
# 1        1368.0                324.0                 2388.0
# 2        3543.0                108.0                 1130.0
# 3        3472.0                123.0                  937.0
# 4        1228.0                 65.0                  829.0
# ..          ...                  ...                    ...
# 593         NaN                  NaN                    NaN
# 594         NaN                  NaN                    NaN
# 595         NaN                  NaN                    NaN
# 596         NaN                  NaN                    NaN
# 597         NaN                  NaN                    NaN
#
#      Viscode-open_file_times  Viscode-success_run  Viscode-failed_run  \
# 0                      439.0               2950.0               255.0
# 1                      254.0               2256.0               132.0
# 2                       73.0               1020.0               110.0
# 3                       79.0                811.0               126.0
# 4                       41.0                701.0               128.0
# ..                       ...                  ...                 ...
# 593                      NaN                  NaN                 NaN
# 594                      NaN                  NaN                 NaN
# 595                      NaN                  NaN                 NaN
# 596                      NaN                  NaN                 NaN
# 597                      NaN                  NaN                 NaN
#
#      Viscode-error_types      Viscode-spent_time  score  class
# 0                   10.0  0 days 02:28:28.302167   91.0      j
# 1                    7.0  0 days 01:24:59.160120   70.0      h
# 2                    8.0  0 days 00:50:32.025803   80.0      a
# 3                    6.0  0 days 00:54:26.187369   90.0      a
# 4                    7.0  0 days 01:06:30.302228   56.0      c
# ..                   ...                     ...    ...    ...
# 593                  NaN                     NaN   91.0      l
# 594                  NaN                     NaN   88.0      l
# 595                  NaN                     NaN   91.0      l
# 596                  NaN                     NaN   95.0      l
# 597                  NaN                     NaN   87.0      l
#
# [598 rows x 56 columns]

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
ax = plt.axes()
ax.set_title('VisCode Correlation')

sns_plot = sns.heatmap(corr)

results_path = './data_plot/VisCode_Correlation.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')

# %% [markdown]
# ## bookroll

# %%
br_pd = pd.read_csv('./data/br.csv')

# %%
#br_pd = br_pd.drop(['ADD_RECOMMENDATION', 'CLOSE_RECOMMENDATION', 'OPEN_RECOMMENDATION', 'LINK_CLICK', 'REGIST CONTENTS'], axis=1)
#br_pd = br_pd.drop(['ADD_RECOMMENDATION', 'CLOSE_RECOMMENDATION', 'OPEN_RECOMMENDATION', 'LINK_CLICK', 'REGIST CONTENTS'], axis=1)
br_pd = br_pd.drop(['CLOSE_RECOMMENDATION', 'OPEN_RECOMMENDATION', 'LINK_CLICK', 'REGIST CONTENTS'], axis=1)
br_pd
# Out:
#                                userid  ADD BOOKMARK  ADD MARKER  ADD MEMO  \
# 0    01291c313aef72b9786046bd7ce4cfca             9         144        12
# 1    019acd030e0cdf674dda03e2a8ca4369             1          81        15
# 2    01ea38c4c3cc5fba869732fc641ca884             7         354        36
# 3    023c88ec58c8cf0abcfbcea4166793ad             1          61        25
# 4    02d679ad650962b6ae8bf8adbeeb33c1             4         188        28
# ..                                ...           ...         ...       ...
# 543  fda96a011b9b53ba6aa39fa978140bdc            39         490        44
# 544  fde0bceed4e87f770bbb3e07bec22d05             0           0         8
# 545  ff352cc412dda02baf83e6c095f81622             0         186        19
# 546  ff6a83db7cd1e89e7f401de25e5edcb7             1           0         0
# 547  ffc7749aa8337fadddcbd42d9cf6e5ec             0          70        13
#
#      ADD_HW_MEMO  BOOKMARK_JUMP  CHANGE MEMO  CLEAR_HW_MEMO  CLOSE  \
# 0             63             64           96              2     80
# 1              0              0           14              0     95
# 2              1              2           22              1    211
# 3              0              0            9              0    290
# 4              8              4           25              0     38
# ..           ...            ...          ...            ...    ...
# 543            2              0          144              0    240
# 544            0              0           33              0     60
# 545           16              0           19              6     78
# 546            0              0            0              0      9
# 547           20              0           13              2     46
#
#      DELETE BOOKMARK  ...  NEXT  NOTGETIT  OPEN  PAGE_JUMP  PREV  QUIZ_ANSWER  \
# 0                  2  ...  2724         0   111        237   889            0
# 1                  0  ...  3321         2   159        109  1584            0
# 2                  4  ...  2209         1   256         67   750            0
# 3                  1  ...  3707         1   325          7  1275            0
# 4                  2  ...  1413         0   138         40   788            0
# ..               ...  ...   ...       ...   ...        ...   ...          ...
# 543                2  ...  3834         1   343         20  1518            0
# 544                0  ...  2105         1   126        188   514            0
# 545                0  ...  2733         0   159        169  1034            0
# 546                0  ...   125         0     9          0     0            0
# 547                0  ...  1593         0    69         26   907            0
#
#      QUIZ_ANSWER_CORRECT  SEARCH  SEARCH_JUMP  UNDO_HW_MEMO
# 0                      0       0            0            65
# 1                      0       0            0             0
# 2                      0       1            0             2
# 3                      0       0            0             0
# 4                      0       0            0             0
# ..                   ...     ...          ...           ...
# 543                    0       0            0             2
# 544                    0       0            0             0
# 545                    0       0            0             1
# 546                    0       0            0             0
# 547                    0       0            0             3
#
# [548 rows x 24 columns]

# %%
plt.figure(figsize=(20, 3))


plt.subplot(1, 3, 1)
br_pd.drop(['NEXT', 'PREV','ADD MARKER', 'OPEN', 'CLOSE', 'PAGE_JUMP', 'BOOKMARK_JUMP'], axis=1).boxplot() # 
plt.xticks(rotation=90)



plt.subplot(1, 3, 2)
br_pd[['BOOKMARK_JUMP', 'PAGE_JUMP', 'ADD MARKER', 'OPEN', 'CLOSE']].boxplot()
plt.xticks(rotation=90)

plt.title('BookRoll Features Distribution')


plt.subplot(1, 3, 3)
br_pd[['NEXT', 'PREV']].boxplot()
plt.xticks(rotation=90)


results_path = './data_plot/BookRoll_Features_Distribution.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
plt.show()

# %%
br_pd = pd.read_csv('./data/br.csv')
#br_pd = br_pd.drop(['Unnamed: 0', 'class', 'score', 'ADD_RECOMMENDATION', 'REGIST CONTENTS'], axis =1)
br_pd = br_pd.drop([ 'REGIST CONTENTS'], axis =1)
br_pd
# Out:
#                                userid  ADD BOOKMARK  ADD MARKER  ADD MEMO  \
# 0    01291c313aef72b9786046bd7ce4cfca             9         144        12
# 1    019acd030e0cdf674dda03e2a8ca4369             1          81        15
# 2    01ea38c4c3cc5fba869732fc641ca884             7         354        36
# 3    023c88ec58c8cf0abcfbcea4166793ad             1          61        25
# 4    02d679ad650962b6ae8bf8adbeeb33c1             4         188        28
# ..                                ...           ...         ...       ...
# 543  fda96a011b9b53ba6aa39fa978140bdc            39         490        44
# 544  fde0bceed4e87f770bbb3e07bec22d05             0           0         8
# 545  ff352cc412dda02baf83e6c095f81622             0         186        19
# 546  ff6a83db7cd1e89e7f401de25e5edcb7             1           0         0
# 547  ffc7749aa8337fadddcbd42d9cf6e5ec             0          70        13
#
#      ADD_HW_MEMO  BOOKMARK_JUMP  CHANGE MEMO  CLEAR_HW_MEMO  CLOSE  \
# 0             63             64           96              2     80
# 1              0              0           14              0     95
# 2              1              2           22              1    211
# 3              0              0            9              0    290
# 4              8              4           25              0     38
# ..           ...            ...          ...            ...    ...
# 543            2              0          144              0    240
# 544            0              0           33              0     60
# 545           16              0           19              6     78
# 546            0              0            0              0      9
# 547           20              0           13              2     46
#
#      CLOSE_RECOMMENDATION  ...  NOTGETIT  OPEN  OPEN_RECOMMENDATION  \
# 0                       0  ...         0   111                    0
# 1                       0  ...         2   159                    0
# 2                       1  ...         1   256                    0
# 3                       0  ...         1   325                    0
# 4                       0  ...         0   138                    0
# ..                    ...  ...       ...   ...                  ...
# 543                     1  ...         1   343                    0
# 544                     0  ...         1   126                    0
# 545                     0  ...         0   159                    0
# 546                     0  ...         0     9                    0
# 547                     0  ...         0    69                    0
#
#      PAGE_JUMP  PREV  QUIZ_ANSWER  QUIZ_ANSWER_CORRECT  SEARCH  SEARCH_JUMP  \
# 0          237   889            0                    0       0            0
# 1          109  1584            0                    0       0            0
# 2           67   750            0                    0       1            0
# 3            7  1275            0                    0       0            0
# 4           40   788            0                    0       0            0
# ..         ...   ...          ...                  ...     ...          ...
# 543         20  1518            0                    0       0            0
# 544        188   514            0                    0       0            0
# 545        169  1034            0                    0       0            0
# 546          0     0            0                    0       0            0
# 547         26   907            0                    0       0            0
#
#      UNDO_HW_MEMO
# 0              65
# 1               0
# 2               2
# 3               0
# 4               0
# ..            ...
# 543             2
# 544             0
# 545             1
# 546             0
# 547             3
#
# [548 rows x 27 columns]

# %%
merge_pd = pd.merge(br_pd, score_pd, on='userid', how = 'outer')
merge_pd = merge_pd.drop( 'userid', axis =1)
merge_pd
# Out:
#      ADD BOOKMARK  ADD MARKER  ADD MEMO  ADD_HW_MEMO  BOOKMARK_JUMP  \
# 0             9.0       144.0      12.0         63.0           64.0
# 1             1.0        81.0      15.0          0.0            0.0
# 2             7.0       354.0      36.0          1.0            2.0
# 3             1.0        61.0      25.0          0.0            0.0
# 4             4.0       188.0      28.0          8.0            4.0
# ..            ...         ...       ...          ...            ...
# 600           NaN         NaN       NaN          NaN            NaN
# 601           NaN         NaN       NaN          NaN            NaN
# 602           NaN         NaN       NaN          NaN            NaN
# 603           NaN         NaN       NaN          NaN            NaN
# 604           NaN         NaN       NaN          NaN            NaN
#
#      CHANGE MEMO  CLEAR_HW_MEMO  CLOSE  CLOSE_RECOMMENDATION  DELETE BOOKMARK  \
# 0           96.0            2.0   80.0                   0.0              2.0
# 1           14.0            0.0   95.0                   0.0              0.0
# 2           22.0            1.0  211.0                   1.0              4.0
# 3            9.0            0.0  290.0                   0.0              1.0
# 4           25.0            0.0   38.0                   0.0              2.0
# ..           ...            ...    ...                   ...              ...
# 600          NaN            NaN    NaN                   NaN              NaN
# 601          NaN            NaN    NaN                   NaN              NaN
# 602          NaN            NaN    NaN                   NaN              NaN
# 603          NaN            NaN    NaN                   NaN              NaN
# 604          NaN            NaN    NaN                   NaN              NaN
#
#      ...  OPEN_RECOMMENDATION  PAGE_JUMP    PREV  QUIZ_ANSWER  \
# 0    ...                  0.0      237.0   889.0          0.0
# 1    ...                  0.0      109.0  1584.0          0.0
# 2    ...                  0.0       67.0   750.0          0.0
# 3    ...                  0.0        7.0  1275.0          0.0
# 4    ...                  0.0       40.0   788.0          0.0
# ..   ...                  ...        ...     ...          ...
# 600  ...                  NaN        NaN     NaN          NaN
# 601  ...                  NaN        NaN     NaN          NaN
# 602  ...                  NaN        NaN     NaN          NaN
# 603  ...                  NaN        NaN     NaN          NaN
# 604  ...                  NaN        NaN     NaN          NaN
#
#      QUIZ_ANSWER_CORRECT  SEARCH  SEARCH_JUMP  UNDO_HW_MEMO  score  class
# 0                    0.0     0.0          0.0          65.0   91.0      j
# 1                    0.0     0.0          0.0           0.0   70.0      h
# 2                    0.0     1.0          0.0           2.0   80.0      a
# 3                    0.0     0.0          0.0           0.0   90.0      a
# 4                    0.0     0.0          0.0           0.0   56.0      c
# ..                   ...     ...          ...           ...    ...    ...
# 600                  NaN     NaN          NaN           NaN   97.0      i
# 601                  NaN     NaN          NaN           NaN   75.0      i
# 602                  NaN     NaN          NaN           NaN   89.0      i
# 603                  NaN     NaN          NaN           NaN    0.0      l
# 604                  NaN     NaN          NaN           NaN    0.0      l
#
# [605 rows x 28 columns]

# %%
#corr = merged_pd.corr()
numeric_df = merged_pd.select_dtypes(include=[np.number])
corr = numeric_df.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
ax = plt.axes()
ax.set_title('BookRoll Correlation')

sns_plot = sns.heatmap(corr)

results_path = './data_plot/BookRoll_Correlation.png'
plt.savefig(results_path, dpi='figure', bbox_inches='tight')
